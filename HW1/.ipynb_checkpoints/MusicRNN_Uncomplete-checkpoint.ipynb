# %% [markdown]
# # Music Generation Using Char-RNN

# %% [markdown]
# In this tutorial we will be training a char-RNN on multiple music files represented in ABC notation (https://en.wikipedia.org/wiki/ABC_notation). We train a char-RNN as a character-level language model. The following diagram shows the application of a char-RNN for character prediction at each time-step.

# %% [markdown]
# <img src="https://i.imgur.com/ZS1iuCh.png" style="height:100px; width:100px"></img>

# %% [markdown]
# An example RNN with 4-dimensional input and output layers, and a hidden layer of 3 units (neurons). This diagram shows the activations in the forward pass when the RNN is fed the characters "hell" as input. The output layer contains confidences the RNN assigns for the next character (vocabulary is "h,e,l,o"); We want the green numbers to be high and red numbers to be low.
# Source : http://karpathy.github.io/2015/05/21/rnn-effectiveness/

# %%
import tensorflow as tf
import numpy as np
import urllib
import os.path

# %% [markdown]
# The following function reads all the input characters in the text file and preapres a vocabulary of the unique characters ```i2c``` (index to character) and a reverse mapping ```c2i```. It incodes the text file as a list of indices in the vobulary for each character in the text file. You can call this function and print i2c, c2i and data to understand the data structures used.

# %%
def load_data(file_path="input.txt"):
    if not os.path.isfile(file_path):
        urllib.urlretrieve("https://paarthneekhara.github.io/input.txt", filename=file_path)
        print "downloaded file"
    f = open(file_path)
    raw_data = f.read()
    f.close()
    vocab = {}
    vocab = {ch : True for ch in raw_data}

    i2c = [ch for ch in vocab]
    c2i = {ch : i for i, ch in enumerate(vocab)}

    data = [c2i[ch] for ch in raw_data]
    
    return data, i2c, c2i

# %% [markdown]
# The function below will be used during training to get a sentence (list of 25 contiguous characters) from the data. The target sentence is offset from the source sentence by 1 index. Refer to the diagram above to understand why.

# %%
def get_sentence(sentence_index, sentence_length, data):
    si = sentence_index * sentence_length
    ei = min(si + sentence_length, len(data)-1)
    source = np.array([data[si:ei]], 'int32')
    target = np.array([data[si+1:ei+1]], 'int32')

    return source, target

# %% [markdown]
# We define our language model below. The model is an implementation of the char-RNN described above. Instead of a simple char-RNN we use an improved model called LSTM which is popular for language modelling tasks.

# %%
class Model:
    def __init__(self, options):
        self.embedding_matrix = tf.get_variable('embedding_matrix', 
                [options['vocab_size'], options['hidden_size']],
                initializer=tf.truncated_normal_initializer(stddev=0.02))
        self.options = options

        self.lstm_init_value = tf.placeholder(
                tf.float32,
                shape=(None, 2 * options['hidden_size']),
                name="lstm_init_value"
            )

    def forward_pass(self, sentence):
        sentence_embedding = tf.nn.embedding_lookup(self.embedding_matrix, 
            sentence, name = "sentence_embedding")
        cell = tf.nn.rnn_cell.LSTMCell(num_units=options['hidden_size'], state_is_tuple=False)
        outputs, last_states = tf.nn.dynamic_rnn(
                cell=cell,
                dtype=tf.float32,
                initial_state=self.lstm_init_value,
                inputs=sentence_embedding)
        outputs = tf.reshape(outputs, shape = (-1, options['hidden_size']))
        logits = tf.layers.dense(outputs, self.options['vocab_size'])
        self.last_states = last_states
        return logits

# %%
# IMPLEMENT THIS FUNCTION
# activations is a tensor of shape (Vocab Size,)
def sample(activations, temp):
    # Implelemnt this function
    pass

# %%
def generate_sample(T = 1.0, sample_length = 1000):
    # seed to start with
    source_np = np.array( [[c2i['<'], c2i['s'], c2i['t'], c2i['a'], c2i['r']]], dtype = 'int32')
    generation = '<star'
    init_state =  np.zeros((1, 2 * HIDDEN_SIZE))
    for i in range(sample_length):
        if i != 0:
            init_state = next_hidden
        
        logits_np, next_hidden = sess.run([logits, model.last_states], 
            feed_dict={
                input_tensor : source_np,
                model.lstm_init_value : init_state
            }
        )

        ch_sampled = sample(logits_np[-1,:], T)
        generation = generation + ch_sampled
        
        source_np = np.array( [[c2i[ch_sampled]]])
        
    return generation

# %%
MAX_EPOCHS = 100 
HIDDEN_SIZE = 200 # Hidden Units in the LSTM
SENTENCE_LENGTH = 25 # Sentence Length Used In Training
LR = 0.0004 # Learning Rate
TEMP = 0.7 # Temperature parameter used to control stochasticity in sampling
SAMPLE_EVERY = 1000 # Generate a sample every x iterations
SAMPLE_LENGTH = 1000 # Max Length of sample to be sampled from the model
BATCH_SIZE = 1

# %%
data, i2c, c2i = load_data()

input_tensor = tf.placeholder(tf.int32, [BATCH_SIZE, None])
target_tensor = tf.placeholder(tf.int32, [BATCH_SIZE, None])

options = {
    'vocab_size' : len(i2c),
    'hidden_size' : HIDDEN_SIZE,
    'sentence_length' : None
}   

model = Model(options)
logits = model.forward_pass(input_tensor)
target_tensor_flat = tf.reshape(target_tensor, shape = (-1,))
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels = target_tensor_flat, logits = logits))


train_op = tf.train.AdamOptimizer(LR).minimize(loss)
# Out:
# downloaded file
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f71d531da90>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.

# %%
print "Vocab"
print i2c[0:50]
print "Data"
print data[0:50]
# Out:
# Vocab
# [' ', '(', ',', '0', '4', '8', '<', '@', 'D', 'H', 'L', 'P', 'T', 'X', '\\', 'd', 'h', 'l', 'p', 't', 'x', '|', '#', "'", '+', '/', '3', '7', '?', 'C', 'G', 'K', 'O', 'S', 'W', '[', '_', 'c', 'g', 'k', 'o', 's', 'w', '{', '\n', '"', '&', '*', '.', '2']
# Data
# [6, 41, 19, 86, 65, 19, 52, 70, 44, 13, 51, 74, 70, 44, 12, 51, 0, 10, 86, 0, 81, 40, 64, 19, 62, 86, 65, 88, 64, 87, 70, 44, 59, 51, 12, 65, 86, 64, 41, 37, 65, 88, 19, 0, 87, 19, 25, 40, 91, 0]

# %%
sess = tf.InteractiveSession()
tf.initialize_all_variables().run()
init_state =  np.zeros((1, 2 * HIDDEN_SIZE))
for epoch in range(MAX_EPOCHS):
    for sentence_index in xrange(len(data)/SENTENCE_LENGTH):
        source, target = get_sentence(sentence_index, SENTENCE_LENGTH, data)
        if sentence_index != 0:
            init_state = next_hidden

        _, loss_val, next_hidden = sess.run([train_op, loss, model.last_states], 
            feed_dict={
                input_tensor : source,
                target_tensor : target,
                model.lstm_init_value : init_state
            }
        )

        if sentence_index % SAMPLE_EVERY == 0:
            print sentence_index, epoch, loss_val
            sample_generation = generate_sample(T = TEMP, sample_length = SAMPLE_LENGTH)
            print sample_generation
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 0 0 4.542019
# Kzd7*d'+hye!
# fDzLmG:JNi~rvHqacB@/xOL>OE*"6'er*Kc=M=-r5d})9cK+}DQ~uVsqDFc\*6FGhHic/gHlbdw.8{Y_zR<c6BeM?=Kh7:O&w):CdU4W-b2O>
# h.bS.f{=\?]Khw2 #Fb}>3.q( {7HoI*rw2&}=_~?"S"01wHfL{F^#d#UyK
# M!e>"N9K>]v6 2)&f!r=PCaPyYOmC+sw]ETc=S_v2zbw?Q"xVR/cJa[aMFv)/J6)3
# S~UgAT
# Gc!26qJ	<r-,|!xS8_XvL1R
# cU1QAD+ROtq 9o]?zre_",vd1DN]sF8CJ]Kn4J
# 9m? \@qx'6jaE|@0ufn"(A]>A.,V/a+Mi0L1!Il}@::+l7
# _ADpr/GmkNA|NODz>RnH"jJOJT(7T*6?."nMT
# IfW4JgOEn>':M7w8:eQE\b69bE8JYH}f<Vfa}9TxV^weL*}RSw#fjQhV8,(TOW1 T_q|k64KRxiV\p5wo<3
# aGhs-a=4?WxcKjnlMq	,kW=:.H,>At\W25sw1S=Bwn,S!RVe~
# 'ne# q{2	rr|Y'a9q/o4XzWs
# 1000 0 2.311238
# <starsaieieonpleec D2oheru tanlorire MMa70tavertae
# ZG/B | B>2ed |
# MrC:uinurt
# :taton er doge dc arri tirLioloriailvieullc pvoonmain -tariiileeenoir catLi
# B:!ort t CBorn ?
# :0:::conetoiierbe
# m:?or
# Z::2it cerer er 4F
# ::-ur
# <an-
# Z:Pru
# r:Fta gvaailleee Zrovsvvosaevee cout MLe5ltrtri coaoouier or t-osauiuugr |e3 d>e f2B2B2 | fAd> |
# B3 .ed | A2B2 B3 c3 d2c | f2d2 f2 | cF2 f2>f3 | BdB dd | c>2c2 B(f3 | ^>BG | f2d> | dBf2 | f2BbB | B3c2cd | fdcd | d2 e>g3 cB | A2 3G/A | A2f3 B2 c>c g> g> cc | f23A| A gBc | B>B>d | B2B d3 | B2Bc | B2B2 c2 c3c | d2f/B | G3 B2 |
# K:
# :P:uarstruioonteslee ("a:iait uerc miazeorretlr leaiuleee MLoaooureet
# :0:- MQS
# -7Id:A
# T:ssaue?ot
# ::1n2
# <:ubSvarobtlF
# M:M:1:urconsaeouteleeee |
# :o:sbcrrtn foul fuevnaitleler aanir mearoagonulii roniatinnet smiootnc ?allrmatieee paigier niah:tarymauut miefor Bu
# K::B2
# 3:c
# :::ornuingrnauce co -
# +:M:Mubuur
# :::M1r
# ::a:rr
# S:d2c ear doe>rroure oairclltuou gbneioeelaieil fautgde
# oorinta crieoleul cirtl :1oirel
# Z:::uv d2
# 2000 0 1.757189
# <staritouuseleldef@fre@f.fre@ffrere
# M:saranat
# T:Care del
# <ssartnce eroutrd? eritalelo M:Macl BEELLON | 4 -05-00-006
# Z:Zra coute sorieillelllolle@ferele.er
# M:224
# C:marate
# S:Praovte eherve
# S:Tr dre oravte paltoriilot eule.O:M:Trnasen eriialoglo@pahelleverefrvere@ee@fr.
# M:1:t
# O:Tra can ouber sobsti Mair Micheh eil pauvrithele eortelmonere ([1964
# K:5
# K:Tbr toute doutouvelelo:M=Mman cill pourinie pallollov fallelf@free..
# L:Gar ence partilougiveo:fa@erve@ff@hfre.fraree
# M:Dran erconsealgle er crisiradl pe? paureiouve ealliolouveloilele.freref.f
# G:Pr tonsaiscor call Mour eill BELLON - 3050-0--32
# z2 B3 | ced | c2A>c | z>B | d2 | d>c Ac | dG cc | d>c/ | B2B | c>G d> | B>B c>c | d> | cd B> | d d>c/ | c>d | FA B> | d>A/f | B2 B2 | B2 Be | c2 | z2 | c>c | d2 G |
# <>Bd |
# <end>d | dc B> | d>c | d2G | c2 | B2 B> | c> G d> | d2d d> | d>f/ | z>4 d>d | BB | B>A2 [c>d | e> c>c | d>c d>d | e>c | Bc/>d | g2 e G | f2z |
# AB | d>f c> | d>B>A | c3B d> | d> B2 | B2 f2 | A2A d> | d>d F> | cGB | c2 e
# 3000 0 1.6992062
# <stariit gisef frat? | Meiel cour tau taltlo Mouschlal fanrailou ouvel eanseile paraseit eEloOuv carit dilhal BELLON - 5005-02
# Z:Lar dom calou etr aith BELLON - 0050-00
# Z:Pour tou ouset oran sailou galle fe larinen M1 c2la co | -00
# Z:Trance
# C:Marte
# C:Arance
# Z:Trande
# C:Caraoutee
# X:Trance et zbrer car gar ge colm tallelouvnen Mourin ct/el etalou stallel Mar2 BEELl | 3 2005--24
# L:Loumou ce tou Matiouton mailouvigle@..
# L:1o:4
# L:Tarate eb tarvait ou Maiih gilou-el pal Mabmet? far courien M192
# Z:Frae d. bbrathou paul Gol? GELLON - B M50050820-
# Z:Pourince
# d:d cd | c3f | B2 dde | e2 fe | Ac B A2 z B2 | F2B | B2A B2 dc | g>c/e/ d2 d2 | f2dfc | egc cc | e4d d2e | e2 g2 | f4 | f2 d2c | f4 BF/A/ | g2dc | Mc2d ef | fed fe | fed G2 | e2 ccd | d>fc | cec ce | c2 1 f2 | B2 FB | B2 B2 | fde dc | g2c d2 | e4 | d4 c>c ed | B4B |B2 c>d | A2cA cd | B2d2 | g2c BA | dddc | g3^A | d2!be z B |
# B2B2B | d2dc | B4 | | [B2B2 | 3 G2 | gecc dz | fef dc | cB BB B2 | A2c d2c | BBB | F4- | B2 c3 |
# FB/B/B/B/
# 4000 0 3.4936297
# <starine? fallouvavitale@free.fr
# O:Prancel
# C:Pronce
# T:Provence
# C:Pranc
# <stronce
# A:Prnate
# R:Palouvence
# Z:Carate
# R:Prance
# C:Polree
# c:| a2 (ef/d/f/ dd/d/ | dB/fB cc/B/c/ cB/d/ dB/ |
# F2B2^f2ed.c>c | c2B2B2BAF| B2)B2B2F2B.|B4FB/B/.ff.d.d.c.c.......G..7.
# <endr
# R:ratalou tarerio parinangenere.
# M:1/4
# L:1/4
# K:Bb
# <:enstritiob par Mainscritiel par Michel BELLLON - 205057
# T:Pour toute observatiion mailto:galoNvielle@fre.fr
# M:1/4
# L:1/8
# K:1]
# B:3d Bd/c/ ddc | cd/d/d/ ed | c2 |
# A4^A....[K:J.raj.
# X:1/86
# L:1/8/8
# T:Fl.brence
# <:tarsta Re lrinain (19)4
# L:Orance
# C:Cove.
# C:Trance
# Z:Transcrd/
# A:Provence
# C:Pout. corviteo Gan pchel BELLON - 2005-07-16
# Z:Pour toute observatilon ain Michelle.
# O:Pranocere
# T:Pnonscrit et/o/e/ouree
# Z:Prance
# R:Franscrit diltouvailelouveriele@free.fr
# M:1/4
# L:1/8
# K:Bb
# V:Bb
# F:Pourret et/ou corrinaig gar Michel (BELLLON - -00-05-07-
# Q:Pou moute obsbrvation maillo:galouvielle@free.fr
# C:1/4
# 3:1/1
# T:Bm
# C:GElj
# <onstilt
# A:Provence
# C:Prove.ce
# C:P
# 5000 0 0.99572563
# <star Michel BELLON - 20005-02-4
# Z:Pour ttoute observatiouvielle@free.fr
# O:Frnancet/.
# Z:Transcrit et/ou corrig? Michell BELLON - 2005-04-07
# Z:Pour toute observatin oiren as Michel per coun Michel BELON - -005-07-7
# Z:Pour toute observation miiclo:gallouvielle@free.fr
# M:inasce
# <start>
# X:14
# T:1/4
# K: Bc | cdc | d3 | ccd | d3 | B4 | G2c | A3) | ""B3FB | e3 | d3 | fe | c3 | A3 | B>c | B3 | c2 | cc | d3f | f3 | de |, g3 | e2 f3 | f3 |
# (3/2 | A3 | c3 | B2c2| d3- | d3d | d3 | d>f | d>c | Bdc | c2z | d3 | fd | c3/2z/ | xd | fg | fgd | d3 | F3 | d4 |
# ced | d3 | "3 B3 | d3 | f2- | B3G | B2 | B3 | c3 | B2 | B2 | cB | c3 | d)z | d3 | c3 | d3 | c3 | c2B | ccB | d3 | B3 | AcB | |
# G2 | c3 | c2d | c3 | c3 | d>e | d3 | A4 | B2B | BB | B/B | d3 | A3z | c3 | c3 | f3 | f3 | c3 |
# V:"/9A)lg |
# | G3 | f4 | fff | gg | ff | f3 | f3 | f3 | gaf | c2d2 | f3 | c/e/ e3 | d3 |
# c3 | cz | B2A2 | d3 | B2z/2c/2e/2 | d3 | f3 | f2 | cz | f2 | dde | d3 | c2 | B3- | B2z | c3 | c3 |
# (F) | d4 | f3 | f3 | f2 | fe
# 6000 0 1.8085697
# <stare dchLLON - 2007-07-2
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:B
# |:
# d2A2 | AG cB | cB zB | BA BBB | c6 |:
# w:Poutile
# Z:Transcrit et/ou corrig? par Michel BELLON - 207-009-
# Z:Pour toute observation maillel euste Bus du tou tar mac pa - ga buren-
# d2 beu | c2 BB | ce dc | dB A2 | "G""DB | AB B2 | AB B | GA AB | A2 AD | B2 GA B2 | GA B/ | BB BB | cd cd | c2 | dB z2 | c2 | BB | A3 | GA AD | BG/B/ A/2B/2 | "C"G2 A/2"GA | AD zB | A2 cB/2 | fg ge | fe ed | cB cc | BB AB AB | c2 cc |
# c2 GE | B4 | "D""G6 | B2 c2 | "C"dd dc | cB BB | cA A>A | B3 | A3 z | AA"BA | AG BA | A2 EB | dd cB | G3"GB | c2 c2 | G4d | d2 BB | e2 dB | BE A2 | A2 AG | B2 AB | d3  :| "
# w:D'e fe dB | "D"G"GA | "G"""GA AB | "D"A2F A2 | A3 | AB BE | A2B V | cc BB | xG z2 | GA AB |
# we A | "G"GG AA | cA BA | B2 c2A | B2 :| AG AB/A/G/ | A/B/ BA | cB c2 | d2c B2 | cd (Bc BA | cd dd | cd cB | BB BB | "A>c c/o/ du | "1 bD g2e | "G"BG c2 | d2c | cB BB | g3- | ec c2 | BA/B/ A/B/ c/2A/2|
# "C"D2 GE B|
# 7000 0 0.7907091
# <start>
# X:17
# M:26
# T:Les courre
# N: D>sinand Ctes
# Z:Nancenser
# M:3/8
# L:1/4
# K:G
# F3|"GEGGB FG|"DABccB|d2e2|:
# "D2"G2G2|A2B2B2|
# <end>
# <start>
# X: 1
# T:Lighelle |1
# R:Burinde pasban dunans B/8
# R:Pour delee
# M:1/4
# L:1/16
# K:Gm
# Dec | d/B/e/B/ BB|c2B2|D4 |:
# |: "G"AABcd2|1CBB.GGGG2|G2A2G2|G8|"DEGGFED|A2G2 F4G2 |
# P:Eurinc dheanan. 17
# <end>
# <stratis>
# X:2
# Z:Gans Bunande
# <start>
# X: C
# L:1/8
# K:Bm
# D2FFDD|D2d2|d2:|:2 GGAFB |: GBcAB|BBd B/GAABG|D4\GGE G4||
# <end>
# <start>
# X:3
# T:Bourre
# R:Bourree
# C:Famules
# R:Bourree Gb brandord tar
# <:Itr an Dan Ju Hhen Winde sou Ahane Bunbonk Mie boned
# <stard>
# C:taven 1 20
# N:"F"d2 | A2G2| "G"G2:| G2 F2|]
# <end>
# <start>
# X:3
# T:La francraitlon dhe chans 1 M'anbe
# M:2/4
# L:1/111
# K:Bmij
# C:Porrig? Maransar tans pant Mif@fralhor Michel@:1
# Z:Badurellel
# L:Tranchetr
# C:Gix dane Hon Jon-
# M:3 Cina transerllor poncharrt on de tundesord.
# M:3/4
# L:1/8
# K:D
# |:AG/GA/A/2A/E/F/|G2B|F2:2|
# <end>
# <start>
# X:16
# T:Bourree
# C:G
# R:Gben BE | Addc| c4| A2D2 |
# 8000 0 0.632337
# <star
# e:Tranne drave sompe
# O:France
# c:Cra?tie
# C:oranlane Coppane Homle
# N:2202
# Q:1/4=160
# K:G
# G4 | "P"EG dA AA B2  |
# B2A G2B2 G2 | d2 cd A2 |"F"A2 Bz | c2 B2 | A2 A2 | G2 AB cd | A2 B2 |
# B3 Bd/2c/2 c/2 dc | d2 cdc|c2 d2B f2 | c2 c2 | AG G2 | A2 cB Ac | cB c2 G | AB cd cA | e2 c2 | dz cB AB | "C"d2 BB Ac cB | \
# <end>
# <start>
# X:2
# T:Carnce
# C:Tranche
# C:Trannane etpou dhampenesde
# Z:<ancritione maithoune etpo: garlon er Michel BELLON- -006-15-06-1
# Z:Pour toute observation mailto:on lailou conielle@free.fr
# Z:Transeste observatie.e.
# O:Tranc.
# S:Trigiog
# Z:Rnancheristaioutu pinto: gin er elt du branse frvaon se bournese
# Z:Trannation er d' et toupie
# N:Cranndrese
# A:Bransese
# Z:Transcrit et/ou corrig? par Michel BELLON - 2006-1102-4
# Z:Pour toute omeseratione eil? (15594
# O:France
# s:1/8
# Q:1/4=0010)
# K:G
# BBcc ddB B2A2:|
# P:Rrid?
# A:Namlane eple s tu tu binane <emse
# Z:Transcrit et/ou grainsse
# :2/4
# L:1/8=16
# Q:1/4"122
# K:G
# "Gm"G4|"Am"FA GA c2 B2F G2 c2 b2 c2  G | c2 cc dz | e2
# 9000 0 2.5409517
# <starolilon (ilto:g/oun-ganl
# M:8/4
# C:Lhovanen de ta O lemas Ci cotis an Cu le tane
# W:ailrils isnte
# T:Transyin (Wallan Mole.mf.
# R:--ilnotrfison aille Cas Tras Cner
# Z:CanslyI on 1587
# C:Tris as ztuir 19y8
# C:Rasoqne de sobsairlail as pan ?rane qis-ande Monde neas des 'saphe
# R:Snis Sot's 19l.nin donlane
# T:anscirn
# M:i1 ha ste lons - at (1)07) Cande
# Z:Misons conmes Aonle
# C:airndel fid ab.
# G:Trande sovlans 1 106 Ponbirnes
# Z:Transcrit oble
# T:Roin (dlave Roube
# O:Firiell' Ballelanen Camas aule masy Ches ande 1
# R:Hoiloalley Honc Bb on chatey senlaaif som-.s
# R:Jilllan-as
# Z:Thhellane (1698)
# Z:Transcrie down
# R:anlen iman 1annser
# R:arislllanes 116 18)
# O:P:ouncer (tolou
# A:Aouref
# C:Wanlonce
# R:Nhain (1)/44
# Z:Tharisw
# R:Tonser)an crane laclane Canle Dhain
# s: at ainame
# C:Thaislan Pollon 2\ (2
# M:mans
# T:Bhan-, Hoslande allan Mois 197)18
# Z:Transcrit ?amla'le aille Canlon sons
# R:anlolle
# K:C
# V:1
# T:Bnaus t"
# C:1aillon dorbe
# M:6/8
# L:1/4
# K:Craj
# d/B/B/ AB | AE F2 GB | f2d2 ec | e
# 10000 0 1.0563147
# <staron (taheltongant D2an sa2 te bottareth>
# T:Made M'olached toleth toub burle Bholthe pla toug ande bentt:"Jan podederold
# C:Turlolough
# H:Thnougen Jadelty
# Z:id:hn-s2-an-1
# M:2/4
# L:3/8
# K:Gm
# AA | BB B2E2 | D2 B2 | B2 A2 | B2 B2 B2 :|
# <end>
# <start>
# X:26
# T:Plarolan (16670-17
# Z:id:hn-n tarolan
# H:Ourlan Cupltle H' tlasen tomes qudett on (177-67
# H:ndarogan intle thede
# M:Cilonde
# C:C"Midess 6 Chelto:ge
# T:Mourlele
# C:Turolan carolan
# C:Turolan (1670-1)33)
# H:Andeolan C'ages tome Janx n st totte tomales tome (1767-427
# Z:id:hn--27
# M:3/8
# L:1/4
# K:G
# D2D2 | GE[F,EC | G2E2FD | E2E2E2 | D2F2F2 | B4 B2B2 |
# B2 B2 B2 B2c2 | a2f2 g2e2 |
# g2 B2A2 | B2B2 B2 |
# |: B2^B2 |
# B2d2 | B2B2 d2B2 | dBBd2 dedB | B2A2G2 | B2B2B2 | BAG4 | D2F2F2 | E>GGAGA | EGF2 D2 | E2A2G2 | E2G2A2 | B4 B2g2 |
# d2B2 B2c2 | BBd2e2 | A2B2F2 | F2A2B2 B2D2 | B2G2F2 | B2G2G2 | B2F2 G2B2 | BAGAG E2F2|D2E2 | G2B2A2 | B>BAG E2E2 | E2F2E2 |
# |: BAG2 | B4B2B2 | G4 | A2F2F2B2 | G2G2G2 :|
# <end>
# <start>
# X:3
# T:O'Carolan-221
# Z
# 11000 0 1.5631175
# <start>X: X:16
# T:Bornaillone
# H:Setmey Darlies Alinge Hony Fornpite, Thed Stayanel Bolhin
# T:Cetne (1 Bane Made (fred Itiun Fhth The
# Z:id:hn-hornpipe-28
# M:C|
# K:Gm
# |:1 (3ABd (3efg (3edc | (3BGG (3Ddg ed|d2 (3efg (3efg | (3edfg (3ged (3AGG | AAGG G2G2 |
# A2BG F2G2|
# ABdg (3fef (3gab | (3efg fede faag|1 (3efg (3edc (3ABc | (3Bcd (3ag dBA |
# A2 (3BdB A (3ABd |
# (3efg (3efg (3def (3be (3fga | (3edf (3ecd (3gag | (3afe (3gfe | gdBA (3Fcd cA|(3AdB A2 (3Bcd | e2 (3egg (3aab (3fge | (3afg (3gde (3BAA | (3GBG (3=cBA (3BAG (3Bc (3cdc |1 BBGA (3FGA | (3Bcd (3cAB A2 (3efg | (3abag (3cdB | (3AcB BA (3Adg (3bag | (3baf (3bg (3edc | (3Bde (3edc (3ABd (3afd |
# cBdf (3age (3bag | AGBA (3AGF G2 | (3ABd (3cAB (3cBd (3cAG | (3FAd (3Acd (3bag (3baab | (3afg (3gag (3badc | (3cAB (3ABc (3egg | (3gag (33dc (3ged | (3gaf (3bag (3gag | (3abg (3agf (3fga | (3cdf (3gbag d2cA | (3Bdc (3Bcd (3dgf (3gad (3edc | d2 edcB cA|AB GA (3AAc | (3efg (3bab e2 (3gab (3gag dcAG|F2FG (3Bcd | (3Bcd (3gag (3edc (3dfg | (3afg (3efg
# 12000 0 1.4480257
# <starione
# |:JdB (3Bcd|ABde|d2fg fedB|
# AFGB cBAG|G2AG (3BdB cA (3BdB|G2d2 c2cA|(3AFG D2:|
# |:C|
# (3AdB (3Bcd (3GAG G2GF|GGBA G2de|bgdc dedc|(3BAG A~G2 |
# <end>
# <start>
# X:87
# T:Partio, The
# R:hornpipe
# C:Seat Hut's The
# R:hornpipe
# Z:id:hn-hornpipe,-)
# M:C|
# K:G
# |:AGAF A2cA|G2BG GcAF|GGAB GFGE|G2BA GBdf|gaag (3cdc d2 (3GBA | (3GBA (3dgf fd (3Bcd (3cBA F2EF|
# (3Bcd fg (3efg gf|~gfec d2cB|cBcd dcBd|efef efec|ddBA A2:|
# <end>
# <star
# X:82
# T:Farbs Che Che
# R:hornpipe
# H:Martion Miche
# C:hutt Jornpipe
# Z:id:hn-hornpipe-28
# M:C|
# K:G
# (3FGB|G2GA (3Bcd (3cdd|=cBcB A2 (3GAF|
# G2GA (3Bcd :|
# |: (3dBd (3BdB dBdB|(3GBA (3cec d2:|
# <end>
# <start>
# X:48
# T:Altin Faveune Stamnin siche
# R:hornpipe
# R:hornpipe
# D:Tlavin Blan tola Hin Cilt Se Baur b's The
# R:hornpipe
# R:heror
# Z:id:hn-hornpippe-88
# M:C|
# K:G
# GF|DBdB G2:|
# |:AGB|A2G2 (3FDC|A2G2 G2:|
# <end>
# <stat>
# X:88
# T:Ced Maftt The
# R:homkane Hodan
# R:hornpipe
# C:Jape Nail, The Dliche
# R:hornpipe
# D:Dadan Staulk,
# R:hornpipe
# C:B
# R:hornpipe
# Z:id:
# 13000 0 0.3763336
# <starions
# T:Mornin the Cothe:
# T:So Brog Jover Stan, #13
# Z:id:hn-jig-4
# M:6/8
# K:Ddor
# AFA AGA|~d3 edB|fge ded|BAB B2G|BAG AFA||
# <end>
# <start>
# X:3
# T:Mortan's an Bart Mornan The
# T:Mornpin: #93
# T:Mornpine Fornin: The
# R:jig
# R:jig
# Z:id:hn-jig-22
# M:6/8
# K:Em
# ABc dBA|AF AGA|BAA d2e|fae aag|age age|dcd ede|dcd e2e|d2e deg|age dcA|BAE ~c3|ede ecd|| eaf fed|~B3 A2d||
# feg aba|gde ged|eag edB|AGA BAG|BGE E2A|cGB c2e|cAF A2c|AAA A2c|AAG ABA|ABd efg|ag efe|dAB AAG|1 EEA A2d|dcA A2A|ABA BA|fef age|fee BAA|GAG DEF|EGA G2G|AGE GFA|dAG G2d|ede d2e|dcA AFA|AGA cAA|dAA AcA|1 AGA Bde|dcd e2e|1 dee ded|~ AAG A2d|ege ded|ecA age|dAA dcA|AGA c2e|1 edB cAG|EGE G2c|AGE B2|AAA A2e|edB B2d|edc d2e|dBA BAB|AGE DEA|BAG E2G||
# <end>
# <start>
# X:33
# T:Migt Bror on Be therrin arn #34
# Z:id:hn-jig-33
# M:6/8
# K:G
# AAc BAB | AGE E2E |1 GAE G2E |2 dBA AFE||
# <end>
# <start>
# X:44
# T:Thelan Jig
# D:Molso Ther tugl Jo Mo Bonnist Stany
# T:Har Rugn on thel #136
# Z:id:hn-jig-8
# M:6/8
# K:Gix
# E3 g3e|dcA BAB|BdB A2A|
# EA
# 14000 0 1.4844481
# <starms
# X:1
# D:Dariatlan in 19
# D:Por came
# Z:id:hn-Mig-8
# M:6/8
# K:Adorrie de an sest statha
# R:hig
# Z:id:hn-jig-92
# M:6/8
# K:G
# | AA AB | Am AB/G/ | A/B/B/ G/A/F/G/A/ | B/d/A/ A/D/2/3/2 A/2/2/2 :|
# AF AF | GA E2 :|
# |:
# |:AB AF|AB AG|AB/A/ ~G3|B/A/ A/G/F/ AB/d/ | e/e/f/ dB/G/ A/G/F/ | AF GE | A/B/d/ e/d/ d/d/F/ B/B/A/ | GB/A/ A/B/A/ A2 |
# |: A/F/A/B/ G/2/A/ | de d/A/e/B/ | cB A/B/d/ d/F/G/|B/d/B/ d/d/B/ G/A/E/ | B/B/e/ g/g/d/ g/e/d/ e/d/e/|e/d/ A2 | A/2/2 G/A/B/G/ B/B/A/ | B/c/d/ B/d/d/d/ ~| e/d/B/B/ A/G/G/ | A/B/d/ d/c/d/B/ | G/F/D/ GA/ B/F/G/G/ | AG B/A/F/ G2 | A2 G2 | AB dG/ A2 |
# |: F A2 | A/F/B/ G/B/G/F/ | A/F/d/ B/c/d/ A/B/|
# |:Ac ~ cA/A/|A/B/A/ F/3 | AB A A2 | B/B/d/e/ g/e/d/ | d/B/d/ gf/g/ | fd e/d/ g/f/g/ | fg/ de/d/ | AB A/A/B/ c/A/B/A/ | dG/ A/B/d/ g/e/B/ | e/A/d/ cB/A G/A/ | AAG A2 :|
# |: G/A/ B/A/B/ F/A//B/c/ | B/A/G/ A/B/c/ =B/B/d/ | f/g/f/e/ d/e/B/ A/B/B/ | BG AB/d/ :|
# P:Variations
# |: ed B2 B/d/d/|e/g/d/ B/d/ | e/e/d/ e/e/b/ e/B/d/ | ed B/B/G/|A/A/F/ A/B/d/ | e/f/A/ A/3/
# 15000 0 1.173831
# <start>
# X:2/4
# L:1/8
# K:D
# AF Bc|d>e ed|ce ge|de Bd|cd BA|BA Ge|de ef|gf e/f/d/|dB BA|GA BA|EG A2|f2 eg|ed ec|dB cA|AG Af/e/|dB A>G|cA A>B|AB ce|dB A2|
# Ad AB|GF AF|G2 BA|d2 G/A/B/A/|GE BA|EG BA|A2 A>c:|2 B2 A2:|
# |:cdB BA||
# <end>
# <start>
# X:16
# T:Marola
# H:Alay polka Cove
# R:polka
# H:Be Keen #100
# M:2/4
# L:1/8
# K:G
# G>A | Bc/G/ G>D|1 A>d BA|BA A>G|FE A2:|
# <end>
# <start>
# X:17
# T:Freed Brsain Golkionk \ The
# R:polka
# Z:id:hn-polka-19
# M:2/4
# L:1/8
# K:D
# EF G>B|AG FE|EG AAB|c>B BA|FA Bc|df eg|ef g>e|dB A>G|A2 D2:|
# |:Af ge/e/|dB AG|Ae ef|gf ed|AB A2|cd B>c|d2 fd/e/|fg e>d|BA GE|G2 GF|d2 A>B|d2 AF|GE/F/ GE|1 G2 GE||
# |:fa gf|ef ec|1 cA AB|d4|ee ce|fe de|gf g>f|ef g>f|d2 e>d|Bd Bd||
# <end>
# <start>
# X:25
# T:Ronnas Page
# R:polk
# D:Deve Polka Dlens The
# T:Soll on Che Bour
# R:polka
# C:Marya polka stesto #20
# R:molka
# H:Id Polka the Po po phe
# R:polka
# A:Seandener to Seet kin Gurko
# R:polka
# H:See allo #120
# H:2/2 an Maclee the Go ta Rer in Bolka
# R:polka
# H:Jellais Wolkain Wonne, The
# R:he-y
# 16000 0 1.8979405
# <starions: s
# HAA BAd|efge defBde|fgdB AGBd|1 d2GA cAGB:|
# <end>
# <start>
# X:8
# T:Jinch Berrion Seging an 198
# D:Tallingar
# R:polka
# H:Sees the thec af the Ch
# Z:id:hn-pigha
# Z:id:hn-polka
# H:Seederat ta the farder Barris in 19, peelye
# Z:id:hn-polka-2
# M:2/4
# L:1/8
# K:G
# Bd/e/g/ gd/g/g/e/|dB GBcd|edcd dBAG|A2Bd Bcdc|dd cAFA|BAFG/B/G/G/G/F/G/A/B/B/A/F/F/F/G/F/G/A/G/ B/AG|ABcd e2de|fee/f/d/B/A/ BGBA|Bcdg ABcd|edBA BAGBG|
# BGBd Bdgf agfe|fgag fedB|GABd BAGA|BAGG AGGED|
# D2G2 Bdefd|d2d2 defg:agef|g2ed BAGd:|
# <end>
# <start>
# X:90
# T:Jhon Bergin M:vear tain Mersie
# R:polka
# D:Marrin Berla the Hally in the Bcartais
# Z:id:hn-polka The
# R:polka
# H:Ameersit tram the Merdel" Mcreet the Wage: Laith oles arda Kister
# R:prickaar
# D:Jiph allis at Margerge al is Trea Martion Aellaygif ster the 1 McKirs Mazin The
# R:polka
# H:2efred in Ssiv is Arechan: the #119,
# D:Madennam Seil Belly 2ornis "Treer tle gfe'terain: The beded|
# D:Jolmig Ss corinn: #28
# Z:id:hn-polka-13
# M:2/4
# L:1/8
# K:G
# BA/c/d/c/ BGBA|G2A
# 17000 0 2.266088
# <starim
# GBef fded|cABc dcAG|AG~A2 dcAB|c2AG EFAG|
# ~G3F FDDD|B2AG FABG|AE~G2 ~B3c|dBAG FDEE||
# |:A2AB cAcA|Be~e2 dcAB|Ac~c2 cAFB|Ad~d2 eddB|cAAG FGGA|1 defd ecEA||
# <end>
# <start>
# X:44
# T:Waister to is Harone the # Aott ans of to Dern 2.
# H:Tliat of bestal post
# R:reel
# C:The Mallione the in ag the and OGllaus Bare Stint is to of tes & "The The Marsion ne varisisher s the Mare sose #134)
# D:Mall The The also Meill #933- Dart ia varteor Cores the theane, #128)
# H:Corteareer od ia plianc.
# D:Mathiar Sting the tough The
# R:reer
# H:chis as to ot in sart corne.
# Z:id:hn-reel-53
# M:C|
# K:Dmix
# d2dc df|ed cAAG|DFDG FDDF|
# AFAG ~F3E|BG~A2 dcAG|FD~E2 FED2|
# FDEF FD~E2|e3g eddc|~E3 FABc|1 (3BcA FD EFDD:|
# |:ag~g2 afge|afge dBAF|G2Gc d2AG||
# |:d2Ac BAdB|cdec dcAB|d2af edcA|(3Bc^c cA~cA | cAAF FGDA | dc~A2 cAE2 | dcAG FDGE||
# <end>
# <start>
# X:52
# T:Mars the #184
# H:Seel ar the to "The ferere "The barrel of to Dare the the verso #543 Leeft tunche se the sifer # we aderelare to "The Marea, The
# T:Bell
# 18000 0 1.6576779
# <start>
# X: (36 AF (3GED | AGEC G3E | (3ABc AG (3Bcd ec|d2 e2fd |d3e dcAF|~ (3FGA d2 (3gfe | d2 (3faf gefe|d2B2 A2df|e2d2 e2de|f2fe ef~e2|
# a2ge d2dB|(3cBA A2 (3Bcd|e2 (3gfe defe|f2 ecde|f2d2 d2de|d2de d2de|f2d2 e2dc||
# e2 (3gfe dc|dAGA GFGF|G2dg fdef|gfec defd|
# cAGA BABA|B2 (3dcd (3efe|d2 (3Bcd e2dB|A2B2 d2ef|
# e2d2 e2de|f2ed edde|fBec defe|c2A2 B2de|
# d2d2 f3e|d2 d2af|e2ge d2de|f2d2 e2de|f2d2 ed~B2|e2d2 efef|~g3f edcA|Bcde fede|
# d2d2 (3Bcd |
# fdde A2de|f2a2 (3gfe dcA||
# <end>
# <start>
# X:73
# T:Jin Muan an (199-198)
# Z:id:hn-alde
# C:Borpon Gand of the Creegland Barnain (197
# H:Also potsin messon of the En Shtingid Rardy Dernion "und in ceackend the the Glasc)
# Z:id:hn-reelsid Marne-
# M:C|
# K:G
# ~E3F GFEF|~G3E GEDF|A2 (3ABd e2dB|c2e2 e2d2|cdef (3gfe de|fde2 d2A2|
# f2ef efAf|gdef e2ge|d2d2 edef|
# e2 (3edf ged^c|d2d2 Bded|BdBA FGBd|e2d2 defg|
# d2fd e2ed|1 B2d2 e2dB|ABdB|A2F2 EDFA|(3Bcd (3gfe d2|f2d2 fede|f2df e2e2|
# g2ec e2ge|dBAF ~D3B|:
# <end>
# <start>
# X:6
# T:Matty (1968-197-890)
# M:C|
# K
# 19000 0 0.18101673
# <starions dece ded:|2 def a2d d2A:|2 dBA GBA B2G:|2 Bdd BdB d2B ||
# P:variations
# |: agf g2 edB | B2e gee dBA | B2d edB edB | Bef e2e g2f | e2d efe dBG | Bde d2B A2F | G2A A2G FGA ||
# <end>
# <start>
# X:515
# T:Dind Stoy & Woy Ssornenthe: Claylind of Liphish, The
# T:Tumis Yir, The
# T:Bumie the Bars of Blore in Gu the "Mc,un Bore the Cublin
# Z:id:hn-slipjig-44
# M:9/8
# K:G
# cdB BAB BcA G2A|B2d B2B A2B|dec Bce edB|A2A B2B d2A|Bdd e2d edB|1 e2a a2f g2e | a2a a2g efg edB:|2 BdB d2B e2d:|2 def gfd efe|dBA A2A A2B||
# <end>
# <start>
# X:57
# T:Cockan's of in Wiure
# T:Himery Ker
# Z:id:hn-slipjig-45
# M:9/8
# K:G
# e2e edB cAF | e2B cBe efe | def g2e d2B | ~f3 efd edc | def gfe def|g2 aga age |2 Bde e2d efd ||
# |:dfe fed edB | def eBc dBA | B2A Bcd cAG ||
# |: efe def g2e | fed dBA ~D3||
# <end>
# <start>
# X:52
# T:Coman Beckin: The of Wumelsy Cort #13
# D:Pady Mcadun: Thef choug, The
# R:hop jig
# M:9/8
# K:Ador
# ~f3 e2d e2f|
# B2d ecd efd|BAG G2G F2G|AGB A2A BAF:|
# |:d2 d2B def gfe|dBA B2A G2A:|2 dee d2B dBB||
# |:
# 20000 0 1.6946678
# <star
# <end>
# <start>
# X:23
# T:Alo the Mol the Halker, The
# R:slinde
# M:6/8
# K:D
# dcA BAd|B2d B2A|B2c d2A|BcB A2G|e2d cAF|A2D EFD|G3 EFA|B2A d2e|
# fed d2f|~a3 agf|g2g g2f|e2d cAA|B2A A2B|
# Bcd g2e|d2g f2d|c2A A2a|f2d d2B|
# B2A A2B|c2B AFD|~A3 B3|A3 D2B|d3 e2d|1 edc dcA:|2 A3 e3|f3 d2e:|2 e3 dBE||
# <end>
# <start>
# X:33
# T:Of Strand's Wisle O'Ders, The
# R:slide
# Z:id:hn-slide-39
# M:6/8
# K:Em
# F2B AFE|A3 AGF|A3 B2B|GBd e2d|B2d edB|c2A Bcd e2d|A2G A2G|A3 A3||
# P:variations
# |: c2A e3 A2B|c2A cBA|B2A A2A|Bcd e2d|B2d ecB|ABA G2A|F2G AFE|G2A B2B:|
# <end>
# <start>
# X:38
# T:Allaterry's Sister, The
# R:slon
# H:See also #3
# Z:id:hn-slide-36
# M:6/8
# K:Dmix
# G2B B2d|e2e f2f|
# d2B B2e|d2B d2B|B2d B2G|d2e d2B|A3 B2d|edc d2e|
# e2d f2e|1 d3 f2e:|2 d3 d2e:|2 e2d cAG||
# <end>
# <start>
# X:38
# T:Morss oo Lair
# R:side
# H:See alsoad in a #1120
# Z:id:hn-slide-33
# M:6/8
# K:D
# D2D D2F|G3 G2A|BGA B2D|1 A3 AFE:D2||
# |:B2B B2B|A2A A2d|B2B d2c|BcB B2e|f2e edB|cde f2f|e2d d2B|~d3 d2d|
# f2d A2B|A2A B2B|A3 F2D|A2B A2F|A3 A2
# 0 1 3.3160305
# <starions
# T:Aveafle
# R:slide
# Z:id:hn-slide-94
# M:6/8
# L:1/8
# K:D
# d2e d2c | def ~a3 | a2f e2d | e2a a2a | fed Bcd | ega ~a3 |
# ~a3 bag | fed efe | def g2e | fed ecA |1 A2B d2e |
# faf gfe | g2e gfe | d2B c2c | d3 d2e |
# fed eec | def fed | d2e c2A | B2g b2a | d2g fed | e2A A2G ||
# <end>
# <start>
# X:95
# T:Seish Saisherty Fart, The
# R:slide
# Z:id:hn-slide-80
# M:6/8
# K:G
# B2A B2A | G2A A2d | B2A F2A |
# B2d B2B | A2G A2F | ABA FFA | A2F A2d |
# B2A Bcd | d2B d2e | d2A Add |
# dfe d2B | ABc d2A | Bcd Bcd | e2e cBA | B2e dcB | AGE A2B :|2 A3 |
# |: e2c Bcd | gfe dcd |
# e2a a2f | e2e ecA | =Bcd e2d | B2G B2c | B3 A3 |
# <end>
# <start>
# X:69
# T:Jo Jouste's
# R:slide
# D:Meee O'Keefe's
# R:slide
# Z:id:hn-slide-91
# M:6/8
# L:1/8
# K:D
# B2e e2d | e2A ABA | A2B c2d | cBA B2c | d3 d2e :|2 d2e e2c | d3 d2e :|2 e3 fed | e2d e2f | g2e d2e :|2 e3 | g3 bag | fed efg | aga a2f | e2e dcA | A2A B2A ||
# <end>
# <start>
# X:88
# T:Paldy Craterios The O'Sair O'Kendellide
# R:slide
# Z:id:hn-slide-92
# M:6/8
# L:1/8
# K:D
# B2d BB
# 1000 1 1.8064159
# <stariel BELLLON - 2005-07-23
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/8
# L:1/8
# K:Gb
# C>fe | d2d2 | B2d>d | e3f g2c>B | AFz B2z | B2 F2>F G2F | B2 Bcd dcd | eag fed | d3 c2d | e2d>d | c2dd | B3c | d3e | edc ce d>c | dce dB dB c3 | ~B3 z2z | fed c2c | cdc d2 cedc | fedc | fedc d2B | cAG ABc | B3 BAB | A3B cBd | cB cB cdd | c3 ABc | d2B2 Bcd | c3c | dc ddz | e2f gfe | c3 Bc | Bz BA |  B3 | B3 :|2 A2(c/B/ GG | F2 G2z |
# F2F2 FG | cA B2A | G3 GF | A3 | F>B cB c)c | d3d | =c/B/B/ AGG | cG BA G>A | cB cB | B2 d>e d>c | d>d d>d c2 | d2B z2z | f3f | d2c B2z | c>d edc | cAB ABG | F3 G2B | c>B AF | FA c2 B>B | Ad d2e | e2B cA | B2z cz |
# B2 d2 dc B2d | cBd | e2f f>e dc | B2A Bcdz | B3 z2z2 | c3c | B2c ezd | d3d | c2d fge | d2 BA B3 | fdc B>d ed | c3B B3z | B4 | c2 A>B z>c | d2c dBc | d>d ddd | cdB c2d | e2d2 efed | feff | f2d efe | d2d (3dc | B2B B2z | A2z B>c | d2d fed | c2c B>c | c>B d3 cB | c3 ce | d3 def | d3 d3 | d>c d=c B2c | B3 cB | B2A Bc | dcd e>d | cBc cAB | AB GBc | B3 AB
# 2000 1 1.4373202
# <stare en-t4
# S:Dance
# A:Provence
# O:DrancB
# A:Provence
# C:Trad.
# C:Trad.
# S: Carno
# O:France
# C:Trad.
# C:Trad.
# O:France
# R:Canset du tou-ti lou le-de ou-li-ta-lo ? se-l?-
# P:Trad.
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-03-03
# Z:Pour tou toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:F
# V:Bb
# d2B2 | B2d2 | B2B2 | c2A2 | BcBB | A>dfe | fded | c2c2 c>cA | G2 Fz |B cB | A2z | B2c2 | B2 f>d | c>d | c>e d>c | d>c d>B | c>B c>d | cE | F>G | FA G>A | G4 || ~G3 | G4 |]
# <end>
# <start>
# X:5
# T:La ca tar coure de - de sa Jou-to ta-lo l?pou-ta-ro pa tambourinaire Finas (1924)
# O:France
# A:Provence
# C:Trad.
# R:Canse trad.
# C:Trad.
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-03-03
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:Bb
# x2BA | B2AB | B2 B2 | B2 | zz | cB c>B | A>B A>B | c>d d>c | B2 d>f | f>e f>e | d>B c>B | A>c d>c | =B2A>B | GA B>A | G>G F2z>A | G>F D>F | A>G G>A | B>B c>B | A>B | c>d d>f | B>A F>F | B2 d>e | df d>c | d>g f>g | f>f
# 3000 1 1.5131018
# <starine Gitallolio:valle@free.fr
# M:2/4
# L:1/8
# K:Bb
# V: caloubet
# f>d | cB/A/ | B2 BB | cd/e/ de | e2c | d2dc | d2ff | f2dc | eg f2 | g2c/4 :| !breath! ("A2 Bc | B2 F2 | G2 Fz | F2 z2 | c4 | cBBc | d2c ded | B>B A2 | A4 | A2 A2 | f2g fef | g2g gfd | edcB | A4 | A2cB | d3B | B2c2 | f2 gfg | f4- | d2c f2ed | ccBc | d4 | cAAc | e2f e2dc | B2B Bc | B2B | B3 BB | B3 z2 |
# BB Bd | fdcd | fgf gG | g4 | g2g d2c | (cde fed | dedc | dfec | cdcc | fedc | e2de | f3 fec | c2Bd | edcB | c4 | cBcB | cdef :|2 d4 | c3 | c2d | B2dB | dgfg | f2dc | d2c2 | fded | c2 d2d | edc | dB/B/ | A4 | cg/e/ dc | fg/f/ de/d/ | g2f gd/e/ | e2dc | fed d>e | dd/e/ dc c2 | fA/B/ AB/B/B/ | cee fe | gedc | d3/2d/2 :| e3- | dc/d/ c>B | A>B B>B | c2ed c>d | c2cA :|
# <end>
# <start>
# X:142
# T:La palla de rain Sname'de= lan blue
# R:Lanstole
# O:France
# A:Provence
# R:Marchet
# C:Trad.
# Z:Trancrite
# A:Marrche
# Z:Transcrit et/ou corrig? par Michel BELLON Lar--220
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-04-03
# Z:Pour toute o
# 4000 1 2.856009
# <star Itreiltos (192)]
# <end>
# <start>
# X:123
# T:Trandt de Gambol
# R:valouse
# C:Provence
# R:Masco
# S:Carnet du tambourinaile lairaines de (1924)
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-24
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# R:Bamado
# A:Provence
# C:J. namec.
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-06-03
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:6/8
# L:1/8
# Q:1/8=10
# K:Bb
# [K:Bbmajor
# gd  | Bz/B/ dc/ | BB/d/ dc | B4- | BA/ Bd | e2d2 | Bd/d/ d3^d | cB/B/ AFF | G2 GA | B2 zB | c2c2 | d2d2 | e2^c (3d/f/ |
# (3d/c/ dd | d/c/d/ dd/d/ | dB/A/ GB | B4 | ed dc | B2F2 | G4 | z4 | d4-| e2d2 | dB/d/ dd | ed/c/ dcd | (e2d2 g2 | A2A2 | BA/A/ BB | c0c ce | dd/d/ dd/d/ | d4- | Bd/d/ ed/c/ | B3 A3 | A4- | A2B2 |B3/2F/2G/2A/2 | B3/2B/2 d2ed/2 | c4- | (3B/2A/2A/2B/2A/.B/2F/2 A3/2B/2B/2 d3/2d/2 c3/2d/2d/2 c3/2B3/2A/2 G3/2A/2| G4B3/2c/2|B3/2B/2A/2 B3-||
# V:2 fis e? le staff=es Sain
# O:France
# A:Provence
# C:?
# R:Mache
# C:
# R:Marche
# Z:Transcr
# 5000 1 0.73814064
# <starialtoo)
# BBdB|d2c d2e|f/2f/2e/2 | d3-|gf | f2d | c3 | d3 | c3 | c2 | cc | B2 | B2e | f3 | fed | cdd | d3 | f3) | (cB/2c/2 | d3 | c/d/=e/f/ | f3 | d3 | d3 | d3- | B/2B/2c/2 | cA | A2A | B3 | AAc | d/B/d/c/ | d3 | cdA | c3 | c2d | d3 | c3- :|
# <end>
# <start>
# X:174
# T:Jamaglo Mar Migel de Reirle dumaiseos
# O:France
# A:Provence
# C:??
# R:Valse
# S:Carnet du tombourinaire Ginas (1924)
# O:France
# A:Provence
# C:?
# P:Vanse
# R:Valse
# C:?
# O:France
# A:Provence
# S:Carnet du tambourinaire Ginas (1924)
# O:France
# R:Valse
# S:Carnet du tambourinaire Ginas (1924)
# O:France
# A:Provence
# C:?
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-22
# M:2/4
# L:1/4
# Q:1/4=16
# K:F
# "Cmammom]
# F2G | Bc | BB | AGA | G3 | d3 | d3 | d2c | dBc | B3 | ded | c3 | d3 | d3 | d>d | c3 | def | g2f | f2f | edd | e3- |
# d3 | d3 | c3- | c2c | G3 | c>z | B3 | B3 | B3 | A3 | B3 | Bzz | "Bd | Bz | (c/2d/2c/2 | B3 | (F/2G/2B/2 | G2z :|
# B2 | cBc | d3 |
# "Gm"B3 | BB | B2B | B3 | B3 | B3 |
# dd/2f/2 | g/2f/2e/2d/2 | c3 | d3 |
# 6000 1 1.2298439
# <staril? par Michel BELLON - 2007-04-02
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/4
# Q:1/4=16
# K:D
# V:1
# AB/A/ Bc/B/|AB AB/A/|B/A/B/ c2 | cB/A/ BG | A2 "D7"AG | B3 | GB BA | c2 cB |]
# <end>
# <start>
# X:36
# T:L'a du da du g? fai-ri? du in du ba-ba-re du ta-ba-
# V:2
# P:vans sar Gancaur ren-ti et pai cou-mais cou-
# P:Anet ui ta-tai-ta se cou-bo le du ta te cour qu pal
# Coube Bu ba-man du bo-tre, du zu-te Bu ren-je du be son- nas cou-lo da coun-re du ta-re da an- - S'e
# x2 | dB | c2 | AB A2 | cB A2 | GB BA/c/ BA | A2 AB | c2 ce | c3- | c/B/A/B/ cB | AG A/B/A/ | AG AG | E/2G/A/2G/2 GA | B/2A/2A/2 B/2G/2G/2 A/2A/2B/2 | G2 AG |
# <end>
# <start>
# X:27
# T:L'a cuuchee
# O:France
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-09-13
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# Q:/4
# Q:1/4=1013
# L:1/8
# Q:1/4=12
# K:Am
# V:1
# T:L'i dou chou le coute sou n'mait (de va be-tous man-san
# <end>
# <start>
# X:14
# T:La noure du pa-be du c'anc du ta-babse Au bas cou-c
# 7000 1 0.5839669
# <start>
# X:11
# T:Dairle berscros
# M:4/4
# L:1/8
# K:Bb
# Bd/2d/c/B/c/|d/e/d/c/B/A/B/c//d/|
# ed/e/d/c/B/c/B/|G/B/B/c/d/e/f/|gf/e/d/c/ B|c/B/c/B/A/ BG|GABA:|
# <end>
# <start>
# X:1
# T:La boneral Dourre nous Denc tou el Hass bamols Sis nonkand in Gile doure Cou nourlle de Boukinard pass and Lui le 1
# R:Bourree
# M:3/8
# L:1/16
# K:Bb
# ABGA BAGA|G2F2GA|AGABc|dedcB|A3GEF|GGABcB:|
# f2af g2fe|d2d2c2B2| c2cdef|edcBcd|A2GABc|B2A2G2|
# cdcB|c2dc|d2cB|d3|A4B2|A4:|
# <end>
# <start>
# X: 19
# T:Le Kane
# R:Bourree
# R:Dave Buland
# R:Bourree
# A:Pronee
# R:Bourree
# A:Proner
# M:3/8
# L:1/8
# K:G
# D2G2|AGAGAG|c2BABc|dcBAG|AGAGAB|A2G2F2|B2A2|G2G2AG|FGABcd|d2cef|g2ggf|bgbaf|d2c2d2|\
# <end>
# <start>
# X: 1
# T:Bourrion bous Masser
# R:Bourrce
# C:Ainarte du tomen
# R:Bourree
# R:Bourree
# Z:Ne noltane
# C:Trie Tuinar
# R:Boure at Mouner
# M:3/4
# L:1/8
# K:G
# FG|F2GA|G2AF|G2FG|FGFG B2|1G2B2|GEGAB|dcBAG|G3:|
# "G"G2F2 FGAB|AGAGEG|BFBcdB|A3AF|GGABAG|G2A2G2|G2G2G2F2:|2
# c4|e2f2e2|dfedc|B2d2c2|GABdef|1c2ABcB|AGAGAG|A2GAGA|c2ABcB|ccBAGF|1G4A4||
# 8000 1 0.53485835
# <starese@fre.fre.prig par Michel BELLON - 2006-11-18
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:8/4
# L:1/4
# K:Gmaj
# B2 BGAG | AG AG A2G | e2 ed ed c | ez A2 G | G2 A2 :|2 d2z fded c2 | A2 G2 :|
# <end>
# <start>
# X: 1
# T:Brensherse
# R:Branse darbelo
# R:Branle
# A:Aransce
# A:Branle
# C:Trad.
# S:Thointese
# Z:Transcrit et/ou corrig? par Michel BELLON - 2006-11-2
# Z:Pour touthee observation mailto:galouielle@free.fr
# M:3/4
# L:1/4
# :16
# |:G2 c2 A2B | "G"d2B2 "G"dcB A2c B2G | G2A G2G | AcB2 A2G | "C"G2 B2 A2 :|
# <end>
# <start>
# X: 1
# T:Eranses de Pranle darnene.
# Z:Transcrit/el et/ou corrig? par Michel et/E/ courghe
# C:Thampain
# N:Crad?
# O:France
# A:Orchesier
# N:15
# R:Branle duanare
# A:Champainse
# Z:Transcrit et/ou corrig? par Michel BELLON - 2006-11-25
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:8/4
# L:1/4
# Q:1/4=200
# K:G
# Zranc>
# Z:<anamnet et/oute mailto:galouvielle@free.fr
# M:8/4
# L:1/4
# Q:1/4=201
# K:G
# dc B2 | c2 G>A Bc d>c |  BA AG | A2 AG AG | "C"A2 A/2A/2F/2A/2A/2 GA/
# 9000 1 1.9031142
# <staron mailto:galouvielle@free.fr
# M:3/4
# L:1/8
# K:Am
# D2 || C2B2d2 | G2G2 | A2B2 | AAAB | A2Bc | B2cBAG | A2AB A2AB | A2B2dB | cBcB c2B2 | A2G2a2 | A2G2G2 ||
# <end>
# <start>
# X:3
# T:Borryel. The Ahane
# T:Pallay coiras
# T:Yavas alland
# C:Sie an conl Jonge ai Morn Paan . a howe
# K:Bb
# A:Lalsa sa mople
# C:Gane covellly Maves ercaith it sten Caplan
# R:Branle de Vallede
# C:Janliss hy Stane The plairal cowter 1648 Oristou
# Z:id:hn-air-25
# M:4/4
# L:1/8
# K:G
# E2 | G2 F2 | GF G2GF | G2B2B2 | A2A2 GABc | B2ABAB | A2AB cBcA | FAGcBA |
# F2A2 B2A2 | B3 AB | AddB cBAc | B2B2 d2ed : c2de | g2ge d2 cBAG | ADGE GBcB | A2G2 A2 A2 | G2AB | c2cB A2Bd | c2Bc d2B2 | A4GA | B2zd d2e2 | G2B2A2 | B2AB cded | (c2B2c2 e2 | d2d2 d2de | (ccdB) A2 G4 :|
# <end>
# <start>
# X:7
# T:Mouplly Can Vais
# C:Mallad Pollane
# R:airne doublane
# C:Ris pos
# B:Crade-wis and Charsie allau
# R:air
# M:3/4
# L:1/8
# K:G
# |: GF | G2 A2 AB | A2 GA G2 AG | (G/2G)A2 | G2 A/B/A | G2 AG AA | GABA :AGAB | A2AA BAGA | D2G3 AB=AA | G4 :|
# <end>
# <st
# 10000 1 0.71677804
# <star>
# X:2 he the tedefe Halty Cecz in #
# W:Ellan t\
# Z:id:hn-carolan-24
# M:3/4
# L:1/8
# K:G
# |: E2 | F3,2 | D2,2D2 | G2E2D2 | B,2G2 G2 | B2E2D2 | FDGA G2E2 | D2E2 G2A2 | F2B2 A2G2 | E2G2 B2d2 | ede2d2 e2f2 | e2d2 B2GF | E4 g4 |
# (3fg2g2 | e2e2 | e2a2 |
# g2f2 | d2g2f2 | e2d2B2 | d2e2d2 | e2e2g2 | f2g2 g2g2 | e2d2B2 | A2A2E2 | A2B2A2 | B3cB2A2 | G2G2E2 |
# D2E2F2 | B4A2 | B2B2 B2c2 |
# B2B2B2 A2G2 | E4A2 | B2G2A2 | B4g2 | e2B2B2 | B3AG2 | G2B2A2 | G4 :|
# |: A2 g2f2 | e2fedB | e2e2e2 | A2F2 A2B2 | A4B2 | B2B2A2 | B2A2 B4 | B2d2e2 | e4e2 | B2c2B2 | A2B2 d2e2 | e2e2 efga | g4fe | d2e2e2 | f2e2g2 |
# B2g2f2 e2d2 | e2A2 efge | d2f2e2 | d4ge | d2B2 B2B2 | A4 B2A2 | B4 (3AGABAFE |
# D2F2D2 B2g2 |
# D2E2 | F2e2B2 | d4 BAB2 |
# B2c2B2 G2A2 | A2G2A2 | B2B2 B2AG | A4 |
# BAFGAG2 | B2B2A2 | G2E2D2 | B2B2B2 | A2B2A2 | B2B2 | B4 B2 ||
# B2B2B2 | F2B2B2 B2AB | B2B2B2 | B2B2G2 | F2G2B2 | Bcd2e2 | e2e2d2 | e2e2f2 | e4f2 | d4f2f2 | e2d2e2d2 | e4d2 | B2BBBB | A4 G4 | G4 :|
# <end>
# <start>
# X:29
# T:Masss Wotbann
# R:ca
# 11000 1 1.223682
# <staripe@frin
# H:Carofigh Sean thelfine
# Z:id:hn-hornpipe-29
# M:C|
# K:D
# (3/B)AG GBde|fgab gedB|cAFA G2AG|
# ABde fedA|BAcB A2 G2:|
# |: (3cde (3fed | (3cBA (3G(FA (3BAG (3BGB | (3AGG (3AGB (3ABc | ddcA (3Bcd (3efd | (3BdB (3Bcd (3cBA (3dcB | (3Bcd (3ded (3Bcd (3edc | (3BAG (3FBd (3efg (3gba |
# bagf (3gfg (3fed | (3Bcd (3BAB (3cAF (3FGA | (3Bcd (3efg (3fed (3cBA | (3Bcd (3efg (3Bdc | B2A2 (3cde (3fdc | (3Bdg (3bag (3gfg (3fed | (3cde (3dfg (3gag (3fga | g2 (3bag (3dBc |
# d2 (3cef gf | (3gab abag | (3aba gf (3gfe | (3dcd (3BAG (3ABc (3ABc | (3ded (3ABc d2 (3cBA |
# GG~G2 (3FED (3FGA |
# D2BA (3Bcd (3efg | aged (3edG (3Bcd |
# efad ecAF | gedB A2 (3AFG ||
# |: (3BdBG | (3BGF (3ABc (3ABc|dB (3GFG (3AGG |
# (3BBd (3cBA (3FED | (3ABc d2 (3cdg (3fag |
# d2 (3efg (3bag | (3aba (3ged (3Bcd | egag (3fga (3bag | (3efg (3agf (3gfg | (3edc (3ded (3cde | (3aab (3gab (3gab (3bag | (3def ga (3bab (3bag | (3eeg (3fgd (3AGA | (3Bcd (3efg (3fge |
# eedB A2 (3GEG | (3Bcd (3Bcd (3efd (3Bdg (3bab | (3efd (3fge (3dBG | (
# 12000 1 1.3544563
# <stare
# M:C|
# K:G
# (3EBd|(3efg fe dBcB|A2Bc d2=ef|gfgf g2ec|d2 (3Bcd cBAc|(3Bcd (3Bcd c2AB |
# G2GF GA Bd Bd (3=BGB|dcdB d2cA|G2GF G2:|
# |: (3ABc d2c2 d2dc|B2=c2 cB A2dc|BABc d2Bc|dcdc B2GB|AGFG A2fe|
# d2Bc ddBG|A2c2 A2 (3ABc|dcBG G2:|
# |:cA|G2 (3Bcd cAGA|BcdB c2AG|G2G2 G2GB|(3ABc (3BAF G2 (3Bcd gB|AG (3FGA A2:|
# |:fg|(3fgf (3gfe dB (3ABc A2|(3cBA G2 (3BcB A2|(3Bcd (3DED (3CDE |
# DGFG GFGB|AGFG A2AF|GAGB d2 (3Bcd|(3efg (c'c'b ag gefg|1 fd (3cde gd (3efg ag |
# agae dcBA|G2D2 A2D2|A2z2 (3EFG A2:|
# |:(3gfe|(3dcB BA GFGF|G2 (3Bcd cega|(3gfe fe dBAG|G2 G2 (3FGc d2:|
# <end>
# <start>
# X:43
# T:Chalieg Mollin
# Z:id:hn-hornpipe-81
# M:C|
# K:Ador
# AF|:GA (3dcB AGED|DGAB c2Bc|dBAG A2AB|cd cA (GBcd AB|A2G2 G2:|
# <end>
# <start>
# X:73
# T:Scamoryeupe, The
# R:hornpipe
# D:Pavas Stottan & Sean Miec in Fum Cromean: The
# R:hornpipe
# Z:id:hn-hornpipe-32
# M:C|
# K:G
# (3GBc|BGGF G2BG|GcBc dc (3Bcd cd|e2AB G2 (3GBd|(3efg ag (3agf ag|(3abd c'bA (3Bcd ^cef|dcd2 (3dBG A2:|
# |:AB|caag ag fedc|dedB AGFF|G2Bd dcBc|d2 (3Bcd
# 13000 1 0.2774213
# <staripe.
# M:6/8
# K:G
# AGA B2A|dBA BAG|~A3 ABd|eAA c2e|fgf bge|dBG Bcd|eaa age|dcB c2c|dcd edB|1 AAB AED:|2 ~G3 ABd||
# |:ede dcd|ege ged|edB cBA|EGA d2e|fed c2A|1 AGE G2B:|2AA A2G||
# <end>
# <start>
# X:42
# T:ornping of the
# R:jig
# Z:id:hn-jig-84
# M:6/8
# K:Ador
# A2A cBA|GED G2A|BcB cAB|cAA eDe|fge dcA|BEG A2A|AGF A2F|EFE A2A||
# |:fed BAB|edc BAB|def edB|BAB c2e|def edB|dcd ged|BAB cde|fdf gab|age def|age cAB|cAA G2A||
# BAG A2B|cAA c2e|fed ceg|1 ~d3 dAF ||
# <end>
# <start>
# X:44
# T:Pond Flang:
# T:Sotro Ron
# T:Kigen's Jig, The
# T:Oveny's Horn, The
# T:Mornpy Sing Turog, The
# T:Do Jaog: The
# R:jig
# D:Mast Jig
# T:Mornpin: Jiginnan
# Z:id:hn-jig-25
# M:6/8
# K:Edor
# ~G3 AGF|DEG AFD|FEF AFD|~G3 AFD|~E3 AFD|BAG A2e|fde dde|ede fed|gfe d2e|faa age|dAG AGA||
# <end>
# <start>
# X:34
# T:Pronet Brobs tande, The
# T:Horny Broggon's
# T:Morne Hornan's
# T:Patry Bry Mounec
# T:Mornin 1.
# D:Roding to ob Broun: Jig #.3
# D:Mith and the Correstin: Over the Mornpin Stonnee.
# Z:id:hn-jig-50
# M:6/8
# K:G
# GAB cBA|~A3 B2d|eaA
# 14000 1 1.065547
# <starth
# H:Steviar
# F:De an at an to Mag and Mobley in Sther
# Z:id:hn-march-5
# M:4/4
# L:1/8
# K:G
# FG BAF | e2e e2e | fdd BAG | AGA B2A :|
# |: AB ABc | d2 d2 :|
# <end>
# <start>
# X:7
# T:Brophirg March
# R:hornpipe
# H:See also #39
# Z:id:hn-march-9
# M:S/4
# L:1/8
# K:D
# DDF AGB|ABc dBA|GEE GBd|AGF GAG|AF E2G|
# EDE A2G|B2d eAA|Bcd eAG|FDE E2E|B2E GBd|dBG FDA|B2 E2E|FDF A2B|
# dBA B2A|B2d dAG|B2G SB3|c2A FGA|BAG B2A|B2A G2A|
# GAG GBd|e2e e2d|ed^B ABc|def gfe|dee d2A||
# <end>
# <start>
# X:7
# T:Parrie Carme
# R:march
# D:Pevie Borch
# D:Mady Burch
# Z:id:hn-march-5
# M:6/8
# K:G
# ~F3 BAG|Ad edA|B2A AB/e/d/|d/A/ B/d/e/d/ | ed c/d/ BA | B/A/G/B/ A2 :|
# |: A/2d/c/ AB/A/|AB/A/ F/E/E/E/|FE G2:|
# |:~f3 gf|gfe dB/A/|B/d/ de/e/|de ec/d/|ed e/d/d/|B/A/ AB/A/|
# dB/G/ A2|B/A/B/ A/c/d/2|bg/ g/a/f/ d/B/|
# <end>
# <start>
# X:7
# T:Bar Dare Fannn
# R:march
# Z:id:hn-marghrist
# D:Me Hiaghan's
# Z:id:hn-march-19
# M:6/8
# K:D
# dB/B/ ABd|ed/A/ B/A/B/|1 c/d/B/ A2:|
# |:g/B/A Bd|Bc dAG|c/B/G F/A/A/|GB/A/ G/B/A/|1 B/A/G/F/ GB/c/ |
# dB/B/
# 15000 1 1.0925145
# <startionsic
# B:Bd BA|GA Bc|de fe/f/|gf ec|d2 dB|B2 A>B|AG A2:|
# |:fe ef|ee fe|de f/e/f|ec de/f/|gf dB|AF AB|cA GA|Bd ef|ge ce|fe d>e|dB A>G|E>G A>B|
# AG AG|G>B A/F/A|df g>f|ec A>d|de fa|fg/f/ ed|eg fg/a/|ge d2|BA A2:|
# <end>
# <start>
# X:24
# T:Vishar Pazurkain
# T:Keer Poyle's Fhellag
# T:Solly Pver Tonn Polka, The
# R:polka
# H:See also played in Blead. #20
# Z:hornpppap/ig-74
# M:2/4
# L:1/8
# K:G
# Bd Be|fe dB/A/|BA BA|fA B>A|GB/d/ ef/g/|1 fe e/f/e/d/ |
# af e/c/A/B/|ce ef|ed Bd|fe d>e|1 Ac BA:|2 AF G>A||
# <end>
# <start>
# X:22
# T:Poldar Polka of Danner
# R:polka
# H:Also played in S.gin
# Z:id:hn-polka-97
# M:2/4
# L:1/8
# K:G
# G>A BG|B>A AA|BA GE|FG E>D|AF A>B|ce de|fe a>g|ed ce|d>B AG|cB AF|G>B A>G|AF A2:|
# |:fe F/e/d|ce fa|gf f/e/f|1 g/f/e/d/ |
# ce ce/f/|gf e/f/g/e/|dB AB/A/|Be d2:|
# |:a>g af/g/|fe ce/g/|fg ed|cA A>A|BA BA|Be d>e/f/|ba be|dB AG|A2 FD|
# A>B AB|ce d>e|fe de|fe ec|ed/e/ dg|
# fe af|gf ed|(3Bcd ce|fg a>f|ed BA|1 A2 AG:|2 G2 G>A||
# <end>
# <start>
# X:23
# T:Sponnerty Sallath
# R:polka
# S:Sela
# 16000 1 1.6447438
# <starn:
# BAG GB|AB cd|ee dB/A/|GG E2|Bd gd|BG GB/A/G/A/|BG GG/A/G/A/|BG GB/A/G/|
# FG AB/c/|d4:|
# |:ed/e/ fa|g2 fg/a/g/|
# ag fa|ba g/e/f/g/|ed BG/A/|Bd Ad/e/|fa fa|ge dc|Bd d2:|
# <end>
# <start>
# X:190
# T:John Coomara[ Reely Colka
# R:polka
# D:Kevin Bergin
# Z:id:hn-polka-70
# M:2/4
# L:1/8
# K:G
# B2 G2A|BAG GFG|AGFA Bcde|fagf edcB|A2FG ABcd|1 d2dd Bdgd:|2 BAGG G2GB||
# |:ddBd cBAB|GBAG GBGB|d2gd BGBd|1 edcd edfa |1 fgge fdcA:|2 A2A2 FED2||
# <end>
# <start>
# X:98
# T:Kersinde Beliver
# T:Treen Beleath
# D:Dely: Cover to Mick Marye 1982 (3978)
# Z:id:hn-polka-90
# M:2/4
# L:1/8
# K:D
# dB/d/ AF/A/|dg/f/ dB|BG B^c|1 BG G2:|2 DF GE||
# |:cA AB/c/|dB AG/A/|BG B/G/E/D/|~E3 Bcd|eb a2|ga g/f/g/d/:|
# |: gf/e/ d/f/e/d/|BA AG|EF DF|A>B cB/c/|
# GF AF/G/|
# GB BA/F/|G^G G2|FA/G/ AG/A/|BA BA|Bd BG|1 AB AG/E/E/G/:|2 G/A/G/B/ GG||
# |:ed cd/e/|dG BG/A/|Bd cd|fa af/f/|dg gb|1 ed d2:|2 fe ed||
# <end>
# <start>
# X:92
# T:O'Kenne Fennain: Chaboteren Hint of Fer cooke on Weated is vertherdin 196, #70
# Z:id:hn-polka-99
# M:2/4
# L:1/8
# 17000 1 2.1341407
# <star/int (reppipedlations
# H:Oftints am reet the Bogs belarke urdelt "The Paddy fert in sith of end the twith sith tet parts.. #3708.
# Z:id:hn-reel-50
# M:C|
# K:Amix
# FE~G2 BGEF|D2EF FGED|FD~G2 ABcd|ea~g2 agec|defg ag~a2|aed^c dfed||
# |:eaag efge|ddd^c d2ec|d2ec dBAF|EFG2 BcBA|
# c2cB cA~A2|ecec dedB|AGFG ABAG|
# FDCF EFDE|FF~G2 EFD2|BcdB BGED|
# ~E3D F2AG|ABAF GABc|dAFA BABA|
# d2af ged^c|BG~E2 EFDF|G2FF cBAB|
# c2cA ABcA|dBGF G2dB|1 AFGE E2ac:|2 ~a3g f2e^c||
# |:faaf edef|gedg edec|~b3a gedB|cBcA ~B3A|
# c2AB c2AB|cAAF EDDE|FDFA BcAB|Ad~g2 edcB|
# cBcA cAAc|dcBc dcAG|FE~F2 GEF2|
# ~A3c eAec|e2dB cBAG|
# cdef gedc|BAAB cAAB|cddc BAGE|
# FG~G2 EAFA|c2BG FDD2|
# c2cB cABc|d2cA Bcde|gfdc defg|adge dBAG|
# FGEG FGAA|BdgB dBGE|~E2 (3FAG A2FA|
# dcAG GFDE|Beg^c dcBA|1 GGAF GED2:|2 dcAG FDD2||
# |:eaag ecAc|1 dcAG FGAB:|2 cdcA A2cd||
# |:egfg agfe|d2dc defg|afe^c eddc|BA~A2 BAGA|GBAG Adfd|
# eA~A2 cBAF|~F3E FDDE|
# F2AG FD~E2|AdcB cAAA|BcBA dde^c|1 dcAG AGE2:|2 dfec d2cd||
# |:eaag efge|fded d2^cd|eaag fed^c|dcBA G
# 18000 1 1.3427513
# <starine
# B^cde | faaf edBd | e2ef gece | c2cA BGBA |
# G2 (3AFG AFGA | (3Bcd ed (3efe d2 (3cAG | A2 (3efe d2 (3cAG | A2 (3gfe dcAF |
# A2 (3cAG FGAG | A2 (3Bcd ed c2 (3cde | c2eg e3d | cAAB cdec |
# A2BA ABce | d2fd efdB | Adfd =cdec | cAGA BGAG ||
# P:variations
# |: (3aFA (3Bcd efdB|cA~A2 (3Bcd|e2 (3fge d2|e2ga gede|fefe dBAG|
# EAB,2 G2B,|
# ~E3  (3^FGAG A2 (3cBA|G2 (3EDE F2 (3GBG|c2 (3efe d2 (3cAG|
# c2AG A2BA|
# B2dB dB A2|FAAF G2 (3def|gfed BAdB|1 AGAF GcAB:|2 fedc A2Bc||
# ~d3d e2dB|1 A2 (3AFE GF (3EFG|A2 (3GFG A2:|
# P:variations
# |:BA BGGA|BdBG FGAB|cBAG FAAB|cABc A2Be|
# B2d2 B2dB|c2B2 dBcB|A2 (3ABc dcBc|dBAG FDFA|
# B2BA BG~A2|B2B2 B2Bd|e2ce f2df|e2e2 d2d2|d2d2 efge|
# d2ed A2Bc|d2 (3efe dBAF|G2 (3cde fd|(3efe d2 edB2|
# (3efg (3gfe dfed|cBAF A2A2| (3gfe (3def gedB|
# BG~B2 BEDF|E2F2 E2 (3DEF|G2BG AGBA:|
# P:Variations:
# A2B,2FA B,2CE|G2B,2 EDDE|D2FA (3Bcd ed|eB~A2 Bcde|
# f2d^c defg|fed2 BAFG|FABG A2 (3fge|d2 (3efg fd|edc2 (3ABG|AFEF G3A:|
# P:variations
# |:F2dB AFAF|G2GE FDDC|D2 (3FED GAFA|d2e2
# 19000 1 0.12215668
# <starg>
# X:83
# T:Firs
# D:Milin Kearing Dord, The
# R:slip jig
# Z:id:hn-slipjig-51
# M:9/8
# K:G
# g|:|: fed cAG G2g | fdB dBd edB | (3ABd g2 edB d2B | A2A B2A B2A | B2e edB d2B | G2G Bcd edA ||
# |: B2A B2A GBd | efe dBB | dBG B2 (3AB G2d |
# e2e gfe dBG | BAG FAA FAG |
# A2A B2e e2B | dBB Bcd edc | def g2e dBA :|
# |: deg ecA BcB | ABA B2d efd |1 cAB Acd e2d :|2 B3 BGB | def gfe dBA :|2 efe d2d e2d ||
# |: efg a2a a2f | afd ~B3 def |
# baf ged efd | fdB B2A G2B :|2 gfe dBG A2 :|
# |: e2a a2a edB | def edB ABA | def gfe dBA :|
# |: afg fec ~a3 | fed edB |1 ded B AGF G2d |
# e2g age dBA | Bcd ege dBA :|2 efa efe fed |
# e2f afd gfe | fed BAG F2A :|
# <end>
# <start>
# X:39
# T:Cary Bourmo
# T:Humours of Ple
# R:slip jig
# H:See also #85
# D:Michaan: Co Fire Michale
# Z:id:hn-slipjig-45
# M:9/8
# K:G
# f/d/B/A/G/ FAA BAG:|2 dBG GBd edB|1 def g2e d2B||
# <end>
# <start>
# X:45
# T:Spipon (1515-1797)
# Z:id:hn-slipjig
# M:9/8
# K:D
# B2d B2G F2G | def ged BAB | dBA GED D2D |
# cAG G2A GBd | edB B2A B2d |
# e2c fed d2B | e2d ege d
# 20000 1 1.4272832
# <starie.
# Z:id:hn-slide-25
# M:6/8
# K:D
# F2G AGF|G2A GEG|F2D DFA|B2E E2D|D2A DEF|E2F G2E|Bcd BGE|
# G2D DFA|d3|BGA B2d|e2d e2d|
# g2g ~g3|efg fed|ecA cAF|1 G3 A2G:|2 A3 G3||
# <end>
# <start>
# X:26
# T:Milie Cairnt, The
# T:Fare or Witle, The
# R:single jig
# D:Mich athe Mill to the Coon the Mill & Weifhried Hartion
# Z:id:hn-slide-31
# M:6/8
# K:Dmix
# A2B AFD|~A3 AFA|G2D D3|F2D DFA|B3 d2e|a2g fed|c2A BcB|1 A2G E2F:|2 A3 B2A:|2 d3 d2e||
# <end>
# <start>
# X:37
# T:Matt Staetaed Iapar Nortion
# R:slide
# Z:id:hn-slide-13
# M:6/8
# K:D
# D2E BEG|A2D D3|A3 A2A|c2A ABc|d2B G2A|Bcd d2B|A2G AGE|
# G2A B2A|G2B B2c|dcd e2d|dfd d2B|1 G3 A2G:|2 d3 d2e||
# |:f2d d2d|e2f a2f|efg a2a|b2a e2d|
# c2d f2d|e2d d2A|B2d e2g|g2e dBA|
# c2d edB|c2A c2d|e3 e2d|1 efe d2B:|2 d3 d2e||
# |:gfe e2d|g2a baf|~g3 a2f|gfe f2d|c2A G2A|1 B3 BAG:|2 G3 A2B||
# <end>
# <start>
# X:36
# T:Mast tuile Keen
# R:slide
# Z:id:hn-slide-36
# M:6/8
# K:D
# D2D FDD|~f3 e2d|A2B A2B|A2A A2F|G3 G2A:|
# |:d2e f2d|B2d B2B|Add c2A|B2d A2F|d2B AGE|G3 B2d|
# A2,2 B,2E|E2D EDE|F2
# 0 2 3.1009812
# <starions
# |: G2A BGA | B2d e2d | e2g a2f | e2A B2A | G2E FED |
# ~E3 B2A | B2A B2A | B2e efe | dcd efg | a2a a2a |
# fed c2d | ecA ABc | B3 :|
# <end>
# <start>
# X:92
# T:Padrie Marter
# T:Carnpet Flachie Charly's
# T:Shats Bary
# T:Of of Selly's
# R:slide
# D:Marte Milly: Ligh
# Z:id:hn-slide-98
# M:6/8
# K:Edor
# A2A AFA | B2F E2F | E2F E2C |
# ~G3 G2e | f2d efe | d2e f2a |
# gag gfe | d2c d2e | fed cBA | B3 dBG |1 A3 A3 :|2 d3 d2e||
# |: f2d efd | efe d2f | ~e3 d2B |
# A2A B2A | def g2e | f2a bag | a2f g2a |
# gfe dcB | ABA A2B |
# e2a a2g | a2f fec | d3 dcd | e2d cBA | G3 :|
# |: eaa g>f | b2a bag | a2f g2e | a2f c2e | fed efe |
# f2e fee | d2B B2A | G3 G2A |
# ~f3 dcB | A2G F2A | B2A G2E |1 G3 G2g |
# f2d d2e | f2e d2B | ABA A2g | fed e2d | g2e dBA |
# f2e d2B |
# ~A3 c2d | efe dcd | efa a2g | f2d edc |1 d3 dcd :|2 G3 G2G ||
# <end>
# <start>
# X:92
# T:O'st O Fanngel's Conny
# R:slide
# Z:id:hn-slide-99
# M:6/8
# L:1/8
# K:D
# e2e efe | dBG A2d | B2E E3 | D2E F2A | F2G F2D | E3 D2D |
# <end>
# <start>
# X:99
# T:Ennis O'Se
# 1000 2 1.3913058
# <starion mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:Ador
# c2c2 | f2d2 | ed c2c>c | d2d2 c2c | d2c BAB | c2c c3 B2z |
# B/c/d ege | d2d fge | d3- d>e | f2f g>g | fe d4 | g2 f>d | f2g fed | f>g f>g f>e | d2B B>c | d3 d>B | c>B c>B c>B | B3z | AF/ G>A B>c | d3 d3e | fdd>d | B3 d3 | e>f f>g | f3 fdd | f2 g>e d>c | d2 dg/e/ | f/g/f/e/ dc/B/ | G3 zz z2 |]
# <end>
# <start>
# X:10
# T:La Bave
# R:Barnte
# A:Provence
# C:Arance
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-22
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:1/4
# L:1/8
# K:Beec2
# A2B2 c2d2|B2c2 d2Bc | f2c2d2d2 | g2e2e | f3 e2e2d2 | c3 d2B2 | (c3c2 | dcdF | A3F | c3 dBA | G3 B2z>B | c3 d2c | B3 z2z ||
# c2dc dcd | B2A B2c | e3d | e4 | e2c B3c | d2d2 ec | d3 d2z | d2d d2c | d2c2 dcB | cAA Bc> dBd | c2A B c3 | B3 z>c | B3 A3 z2z |
# ABc dcd | A2c A2G | c2d c2B | B3 B2d | c2z G3 | B2A c2c | B3F G3 ||
# T:Bor Mour Bunte
# T:France
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-23
# Z:Pour toute observation mailto:galouvielle@
# 2000 2 1.4017873
# <starie. (18234|]
# <end>
# <start>
# X:24
# T:Le diso li do lou de lou dou-lete-tro
# O:France
# A:Provence
# O:France
# A:Provence
# C:Trad.
# R:Danse trad.
# S:Trad.
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-03-03
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:Bb
# B>c | d>d | c>B A>B | c2 d>c | d>c | d>f | e>e cB | c>B A>G | F>A B>A | G>A B>A | B>A B>c | d>c B>c | d>d c>B | c>d d>g | f>e c>d | e>d c>B | c>c d>e | f>d d>e | c>B c>d | f>g f>e | f/f/e/d/ cd | f>e d>c | B>A A>G | A/f/2d>>d e>d | cB | A>B | c>d c>A | G>A B>A | c>B c>c | d2 c>d | e>f A>B | c>d e>d | c>B c>d | e>d c>B | G>F A>B | A>B A>G | z>d c>d | e>d c>d | e>c B>A | B>B c>B | c2 F2 | G>A | B2 G>A | B2 z>f | e2 z>c | d>c d>e | f>e d>c | d>d c>B |
# c>B B>G | AGA | B>c | d2 c2 | d>B | c2 B>A | f>d c>e | A2 z>>B |
# c>e f | f2 | c>d | e>d ef | df e>c | dg | d>e d>c | B>B | B>c d>e | f>g f>g | f>g f>e d>c | B>A G>A | BA G2 | E>E |
# zd | B>B c>d | e>d e>d | c2 B2 | d>cd>e | dz z>A | d2 fd | ce d>c | d>d c>B |
# 3000 2 1.3629898
# <stare@free.fre.f
# M:2/4
# L:1/8
# K:Bb
# V:1
# A2G Bdd | e2d2 | c2c c2 | e2c2 | d2df | e2c2 | efed | fedc | BBcd | edef g2fe | d2cd c2f | f2fd cBc | d2d dc | B3B | f3 g3 |
# fefe | dff=e ddB | f2d fde | d2c d2 | cA Fz | (3G3 G2G |
# A2 c2 | c2c | d2d2 | dcde | f3 g2g | f4 | f2g f2e | d3 d2c | d3 B2B | cBA Bc | B3 z2z :|
# L:1/8
# K:F
# F2B>d | cAc d2e | d2>d c2A | cB/A/ GB | c2c2 | cB/c/ BE | F2F2 :|2 f4 |
# ed ef/e/ | d2d ed | ccB cd dc | d4 | c2 c2 | d3/2c/2 c(d/c/) |  df/d/ dc | d3 |  FA/d/ cBA | G4 | F2- |
# zz |]
# <end>
# <start>
# X:113
# T:L'a fesso cou-rinsancale
# O:France
# A:Provence
# C:J. Ginal
# R:Marche
# C:Trad.
# R:Marche
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-03-03
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:6/8
# L:1/8
# K:Bb
# V:1 c'ambend?
# <end>
# <start>
# X:100
# T:La Marche Resso
# O:France
# A:Provence
# C:Trad.
# R:Marche
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-02-24
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:6/8
# L:1/8
# K:F
# V:1
# B2c2B2 | e2
# 4000 2 2.3151593
# <stare
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-13
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# Q:1/4=106
# K:Bb
# V:1
# A2 A>A | BABc | d2d2 | d4- | e2d2 | c2d2 | cde2 | d2d2c2 | B2z2F2 |
# Acde | dfed | c3- | d4 !breath!A2 (cd) | (ed)(d/) (d)d | e2c | dB dd | d2d2 | (3d/d/d/d/ d3/2d/2 | e2d2 | d2d2 | d^c2d>d | ed/c/ B4 :|2 G3/2A/2 | B>B | B>c d2 | c>B dc |
# df/f/ d(3e/2d/2 | ed/c/ dd | GF/G/ AB | A(3B/c/d/ ed | c4- | B2- zz |]
# <enc>
# <start>
# X:13
# T:Vendo du Boulo
# O:France
# A:Provence
# C:Por?me
# O:France
# A:Provence
# C:?not
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-27
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:Bbmajor
# A2>A2 A>G | A2FE | F4- | A2A2G2 | B2>d2 AB | c2z2 | ^F2A2 | B2A2 | d2c2c2 | c2c2c2 | d2z_ed | d2d2 fd^c | d3- d | d2e2 | dcde | f2g2f2 | gff fd>e | d8 | fed ded | c4- | G3 |
# AGA Bcd | d4- | d2d2 | (3dde | dd de | f2z | f2e2 | dd2 cdc | BB/c/ BA/B/ | c2c2 | B2B2 | B2B2 |
# B2B BA | B3- | G2B2 | dz
# 5000 2 0.59382594
# <starconalinel)file.freath.F. F2. |
# "Bb"B | "Dm"FBB | "F"B2B | A2GF | d3 ::
# P:A
# Ac | d3 | cBc | B3 | B2z | A3 | e2c | ccA | A3 | c2d | d2c | B3 | c4 | B2A | B3 | BAB | B3 | c3 | ddB | c2A | B3 | czz |
# | g2z | g2 | f2f2 | "F7"c3 | d2d | fed | ez) | (c3 | B3 | b2f | fe=e | f3 | f3 | fed | c3 | d3 | d3 | d3 | c3 | c3 | dcB | A3 | GAB | d3 | f3 | c3 | fgf | cBc | B3 z | f3 | d2c | B3 | c3 | d3 | c3 | cBA | B3 | d2f | f3 | fcd | c2F | G3 | ABA | G3 | [1 G3 | ccc | =eee | d3 | d2- | d3 | "C"G3 | "Ab"ABc | "Gm"c2B | c3 | d2z |  d3 | e3 | d3 | az | ""F"B2c | "Bb"fed |
# "F"d3 | "Gm"B"E3 | "F"G2 | "Em"c3 | "C"c3 | A>B | "C"cAA |
# B2 B | "F"B3 | "G"G3 | (B2F) | (B3 | d3 | d3 | d3 | =G3 | B3 | B3 | G3:|
# Q:16=110
# T:La Mallo de coumpouri Gi ?m? prolis sta va lu dan, Seige
# O:France
# A:Provence
# C:Pride
# R:Vanse
# Z:Transcrit et/ou corrig? par Michel BELLON - 2000-07-04
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:3/4
# L:1/4
# K:Bb
# V:1
# d>Bc | d3 | eA A | c3 | d3 | c3 | B3 | G3 | G3 |
# 6000 2 1.1050085
# <stare
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-04-26
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:G
# V:1
# P:A
# cd e2 | e2 ef | e2 fe | de dc | BB B2 | z2 z2 |]
# <end>
# <start>
# X:30
# T:La moun dans das cou-te
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-04-27
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# Q:3/8=120
# T:Brende
# C:Trad.
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-04-27
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# Q:1/4=120
# K:G
# V:1
# P:D
# d/2c/2B/2A/2 BG/2A/2 G2||
# w:1/8
# ...
# M:6/8
# K:Bb
# fed dcB | A2c BAG | F2F F2A | G3 z2z | f3 z2z | B3 | GAB | c2d | c2z | B2A |
# B2B | B2B | B2B | A2B | AGF | GcB cde | d2
# 2000 17 1.2792845
# <startht][c2cB | c>de>c | d6 | c>de>c | d>dc2 | B>AG>E | F>Af>A B>c | d>B d>d c>e | d>cB>d g>fe>d | c>B A>G F>AF>A | G>A B>c d>e | f>d c>B A>B | c>d e>c d>e | f>d c>d e>e | d>cB>A G>e | d>c d>e !breath!B | d2d d2 | d/e/f/g/ f/e/d/e/ |
# Bd d/e/f/e/ | d/e/d/c/ dB | f/e/f/e/ d/e/f/e/ d/d/d/e/ | d/d/d/>d/ |
# e/d/e/d/ cB | A>G FA | G>A BG | B>c d>B | d>d c2 |]
# <end>
# <start>
# X:68
# T:Lei coure de la Marter
# R:Contrez
# B2B A2A | B2B A2F | (F2F A2A | G3) | (A/B/)A) | B2G | A2c | B3 | c3 d2d | c2c2 | c2B | A2 | f2F | B2> | d c d2 | fe d | e2d cBA | G2A c2B | A2A A2e | cB A2f | c2d e2d | cBA cFA | c2A A2B | A2G | d2d | c2B | A2B | cdc | cdc | A3 |
# cB A2 | cc/d/ cd | cB cd | ec dd | c2 BAG | F2G A2A | B2z zc | d2c c3 | d3 de | d2d d>ec | Hd2d d3 |]
# <end>
# <start>
# X:49
# T:Lou coure de la carbe?es
# R:Danse trad.
# S:Carnet du tambourinaire Ginas (1924)
# O:France
# A:Provence
# C:Trad.
# R:Danse trad.
# S:Carnet du tambourinaire Ginas (1924)
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-03-06
# Z:Po
# 3000 17 1.1716833
# <start? part?pe Ebre
# M:6/8
# L:1/8
# K:Bb
# V:Galoubet
# d | d2B2 | f2f2 | g2e2 | f3z |5 zd2^F | G4 | F4-F2 | B2 G2 c2 | d2B2 | c4 | cd ed | c2 F2 | c2cc |
# BB B2 | A4- | A2 GA | c4 | cB AB | A2dc | BA cA | f2 z2 ||
# [K:C] A2 A2 | A2 Ac dc | B2 FA Ac | Bd dc !breath!d ff | fff gfe | d2d ded | cBA cBc | BAB ccc | A3 zfe | fgf fed | c3 ced | e3- cec | d2B A2B | A2A A2z | F3 z2z | A4- | A2A A2A | B3 z2z | B2z B2B | c2A B2c | d2e d2B | f2f f2e | d3 e2F | B3 GAB | c2F f2f | =e2d c2B | A4 cA | B3 B3 | c3 cde | f3-.b |
# f4 d2 | e2dc d2B | e2e e2e | d2c B2B | B2B B B2B | B2B !breath!d2 c2 | B2d B | d4 | c2 d A F2 cc cd | c2 B/A/B/c/ dB | cB BB | B2 cc |
# BE FB | A2 F2 | Bz F2 | F2 F2 | B2 z2 |]
# <end>
# <start>
# X:91
# T:La Gourdiorello
# O:France
# A:Provence
# C:Arnazu
# Z:Transcrit et/ou corrig? par Michel EELON - 2005-04-23
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:6/8
# L:1/8
# K:Bb
# V:Galoubet
# dd | f2ff/f/ | g2g | fgfa | gd/c/ B2 | d2B2 | G4 | F3G | A2>G | A6 | F2 G>A | B2 G>B | d4 | c3d
# 4000 17 1.0182396
# <star)
# M:3/4
# L:1/8
# K:Bb
# dA  (B/A/)G3|B2c d2d|c3- Ac | (de) ((3d/c/) |
# AA/B/ AA/B/ | cc cd | c2-A GB | A2A2 | B2 Bc | d2>d2 | def2 | e2c2 | e4- | dc BA | G4- | G>A Bd | d2>c2 | d4 | d4- | d4- | d^cde | dd) (3B/d/d/ dd | e2d2 | f2 z2 | F>G AB | c>A B>c | d4 | d^cde | d4- | d4 |
# d2d2 | c2 F>G | A2 B>c | d2d2 | f2>f2 | e2hd2 | c4- | c4- | c2> B2 | e2 ed | c4- | c4- | cd ed | c4- | c4- | cBAG | c4- | cB AG | A2z2 | cB AG | G4- | G4- | A4- | A4- | A2 A2 | A4- | A2 A2 | c2 dc | B4- | A2 Ac | d4 | c4- | A4- | A2 Ac | A2 dc | B2 z2 | B2> Bd | dd dd | d(3c/c/=B/ c2 | d4 | e4- | d4 | d^cde | d4 | d4- | d4 | d3edc | B4- | B4 | A4- | F2 z2 | G2 F2 | G4 | F2f2 |
# f2g2 | f>d B>d | e2f2 | e2d2 | ed cd | ccc2 | d4 | d2d>c | B2B2 | B>A B>c | d>c B>A | B>B d>e | d2B2 | c>B c2 | d>d e>e | d4 | c4- gz | c4- | c>d ed | c4- | B2> GF | G2 G>G | g4- | a2 f2 | g2 z>e | d2c2 | B4- | B4 |
# d2 f>e | d4 | de d>^c | d2d>e | c2d2 | ee f2 | d2> d2 | d2>d2 | f2> d2 | c2> G2 | A4- | A4- | A2 A>G | A4- | zF/F/ F2 |
# (
# 5000 17 0.2917953
# <start:safUtaVe=he<sto.hM:3/4
# K:Bb
# "ritolto plunet tourtel to to goube? nouco
# R:Valse
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-26
# Z:Pour toute observation mailto:galouvielle@fre.fritt.M:3
# L:1/8
# K:Bb
# V:1
# GF|B2B d2d|dcB c3|B3|d3|B3|(c2d)c|B3 (d2B| d3) | (ddB)|G3 | g3 |
# d3 | (c3 | g3- | (d3 | d3 | e3 | d3 | dcd | d3 | c3 | f3 | d3 | d3 | G3 | B3 | B3 | B2B | B2B | B3 | B3 | F2d | B3 | d3 | f3 | ccc | c2z | (Bcd | g2f | \
# |: cde | d3 | d3 | ddd | e3 | d3 | e3 | d3 | c3 | c3- | dcB | A2A | F2A | B3 |
# Bef | fec | A3 dcd | e3 e3 | d3 dcd | e2c d2e | f2f f2d | c3 |
# c3 | c3- | d3 | c3- | czz | A3 | B3 | B3 | fzz | B2A | c2d | c3 | cBc | edc | fgf | fed | dc2 | cAc | d3 | c3- | d3 | c3- | c3- | d3 | ezz | cdc | B3 | "F"AF | d2d | fgf | e2A | B>AG> | F>EG | A3 ||
# <end>
# <start>
# X:160
# T:La pamour la gran
# R:Valse
# S:Carnet du tambourinaire Ginas (1924)
# O:France
# A:Provence
# R:Valse
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-16
# M:3/4
# L:1/4
# Q:1/4=160
# K:Bbma
# 6000 17 0.51201075
# <start:
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-04-06
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:G
# V:1
# "D"dd/2d/2|"E"AA "C"cd/2c/2|
# "g"fg/2f/2 g2|:
# "F"fg/2f/2 e2|:\
# "G"A2 "G"dB|"D"A3>D|"D"A3A|"G"GG "D"A2 A2|"G"GB BA|"G"Gg Bd|BA GA|BA GB|"D7"Ad A/2B/2|c3/2B/2 A2||
# |:"G"Bd Bd|B/2c/2B/2c/2 "Bb"Bd|c2c/2B/2 c2:|
# <end>
# <start>
# X:23
# T:Polka n? Lout, d'ub
# R:Johnair-2-1
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-04-27
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:G
# V:1 G
# K:C
# d3eef g2G3/2A/2|B2c2d2|(c2c2B2A3z:|
# <end>
# <start>
# X:22
# T:La couto
# C:Trad.
# O:France
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-04-27
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# Q:1/4=100
# K:Am
# V:1
# Gd||:d2d|c2d edc|B2G B2G|A2G A2c|B2 G A2 z|B2 z2|
# w:Qui n'tenait a mous le souis-
# cd ef | ge ae | fe dc | BB cB | A2 GA |
# B2 cc/B/ | A/B/c/d/ BG | A/B/c/d/ cd | ed cB | A2 c2 | cA GA |
# w: L'a ren du bies te
# 7000 17 0.44355994
# <start: - Sonagh Le 192 b??derisien.
# Z:mals/4
# M:3/8
# L:1/8
# K:G
# d2 c2|B2 AB cd|f2 d2|ge d2|\
# d2 e|fed|de dc|f2 fe|dB G2:|
# <end>
# <start>
# X:1
# T:Bourr?e Tur?
# C:Allacks
# Z:id:hn-san-5
# M:6/8
# L:1/8
# K:G
# AB/c/|AG AG|F/G/A/^F/G/|A/G/^F/G/|AG F/G/A/B/|1EG ABc:| \
# ABc|ded|cde|dBB|c3|ABc|1 G2A:| B2c B3|]
# <end>
# <start>
# X:1
# T:Bourr?e Tross
# R:Bourree
# C:J. Ginas
# Z:Transcrit et/ou corrig? par Michel BELLON - 2007-06-09
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/8
# K:G
# B2AF|GEE D2D|GFG A2D|FEF GAB|cBA)|GAd|GGA|BGB|d2A F|G2F A2c|B2A GAB|G3||
# ABA GEE|A2A BGA|GFG A|\
# G3|c2A B|c2d cBA|GEG AGA|Bdd F|"C"c cB|EFG|ABc A2A|1 DFG:|2 FDD||
# d2e|cde|dcB|ABc|dBd|ede|d2B|cBc|d2e|1 fedc:|2c3|]
# <end>
# <start>
# X:3
# T:Les Bramond Charle
# C:Ging a Senet transcrapiel Hersince.
# M:3/8
# L:1/8
# K:G
# Gc|BA GA|Bd cB|A2A3|G2A|BGA|BAG|AGG|A2A|FGA|B2G|GAB|GAB|GA/B/A/B/|cBA|1GEF:|2G3||
# A3|:\
# A>BA|FAG|FGF|GFG|GFE|D>AB|GA/G/|AF)|G>A Bc|B>G GB|d>f ed|1 cBA:|2A2G||
# w:(Mab Lestre Granle (172
# 8000 17 0.38766003
# <starti<l<na>I
# R:Branscrip tambourinion: nabut Barrane Waithim. Air du loup en sermmit.
# N:Art andourdunded.
# R:Ronde
# C:Trad.
# S:Thoinot Arbeau
# N:0165.gif
# B:Orchesographie (1589)
# O:France
# A:Champaigne
# Z:<anamnese@laposte.net> -- http://anamnese.fr.st
# Z:Transcrit et/ou corrig? par Michel BELLON - 2006-11-25
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:8/4
# L:1/4
# Q:1/4=220
# K:G
# GABd d2d2|d2c2d2|G2G2B2|G2B2A2A2|A2B2A2G2|A2B2G2|A2G2B2|A2G2:|
# e2g2 fedc|B2 B2B2|c2e2 e2c2|B2 AG FG|E2 AB Ac|de fe dc|1 B2A2 G2:|2 A2 A4||
# P:Ron pro
# C:Trad.
# S:Thambert tu branse de Charloundants brancher"
# Z:Transcrit et/ou corrig? par Michel BELLON - 2006-11-25
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:8/4
# L:1/4
# Q:1/4=200
# K:F
# B/2c/2d/2c/2B/2A/2G/2A/2 B B| \
# cd c/B/A | dd/d/ d/d//c/d/ c/d/c/B/ | cd cB | AG GG |
# w:scprich transcaith is berre bidd?
# Z:Aire desce or 5?82.
# D:Tradumim. Lid?u br?me nimo
# M:3/4
# L:1/4
# K:G
# G2A|B2c d2G|E2A EGA|ddd|"C"e2d edc|"C"e2d e2d|"G"d2d d2d|
# 9000 17 0.6881712
# <start: aassept?
# Z:id:hn-air-21
# M:3/4
# L:1/8
# K:G
# B2 | A2AA A2 | G2 GA | G2 Bc | d2de | d2B2 | c4 | AGFG |
# B2BB | AGAB | A2GABG | A2B2dB | A2G2AB | AGAB df :|
# <end>
# <start>
# X:1
# T:Ban-si jeu
# T:Air of Paire
# R:air
# Z:id:hn-air-6
# M:3/4
# L:1/8
# K:Bb
# d2 Bd | e2 d2 B2 | A2 B2 d2 | e4 e f g2 :|
# |: deff | gagf | e2fe | dddd | e3d | e2 de | f4 |
# (e>e) dB AB | c4 :|
# <end>
# <start>
# X:63
# T:Nille duis d'As Chandelian
# C:Christon Chempair
# O:1703
# Z:id:hn-air-7
# M:C|
# L:1/8
# K:F
# V:1
# G2ABGB | d2d2 | G2A2B2 | G2B2d2 | e4de | d2d2d2 | e2e2d2 | A4B2 | A4G2 | G4G4 | G4 ||
# G4A4 | G4G4 | G4AB | A2BcBA | G4G2 | G4AB | A2B2c2 | B2A2B2 | A3G | A2B2d2 | A2GAB2 | A4A2 | A2B2d2 | d2d2e2 | f2g2f2 | e4d2 | d4B2 | A4F2 | A2B2A2 | G4 ||
# A2B2c2d2 | e2e2d2B2 | A4c2 | B2A2G2 | A2B2d2 | e2c2f2 | g4G2 | g4a2 | a4b2 | a4g2 | g4 g2e2 | (c2d2)B2 | B2AB |
# d2^cdcB | A2d2c2 | d2dcBA | G4G2 | G2BcdB | A2G2A2 | G2A2 | B2A2 | G4 ||
# g4e3 | e2dg | a4a2 | g2edcB | A2d2e2 | d2B2d2 | g4a2 | bagfe2 | d4B2 | c4B3 | A2
# 10000 17 0.29225007
# <starto] gag | g2b | agf | e6 |
# d2e d2c | e2d e2c | B2B A2G | F2D D2F | E2 F2 E |
# D2 | D2D D2A | B2A G2A | BAG E2F | B3 cBA | B2E E2 :|
# |: B | g3 gag | fed c2A | B3 BAG | E2 F2 G2 ||
# <end>
# <start>
# X:20
# T:Mord Sellan Halla
# T:The Englin
# R:hornpipe
# C:Franle Gardord
# C:Jackie galon
# Z:id:hn-carolan-29
# M:3/4
# L:1/8
# K:G
# B | A2A2 | A2 FGAF | G2A2 BAGF | E2c2 A4 |
# dedB G2 B2 | A2 B2 AG | E2 ED E2 | E2 D2 ||
# |: BA | GBdG | EGGB | AB G2 | ABcd edcB | A2 d2 BA | GA Bc B2 |
# B2 B2 AG | E2 E2 E2 | E4 ||
# <end>
# <start>
# X:24
# T:O'Carolan's Connon's
# R:carolan
# C:Turlough O'Carolan Thorabh parts: whell.orguis Marge"
# Z:id:hn-carolan-28
# M:3/4
# L:1/8
# K:G
# BA | BG EG E2 | D2 AB | D2 B,2 | D2 D2 | E2 E2 | E2 E2 | D4 :|
# |: B | edef gede | d2d2 edef | g2 g2 g2 |
# e3f e2Be | efed BdBd | e2ed eged | cBAG BGBA | G2F2 E2 :|
# <end>
# <start>
# X:25
# T:O'Carolan's Devera
# R:carolan
# C:Turlough O'Carolan (1670-1738)
# H:Often played ating and dans from sindle stapert 2007-2t. Hen tune do hous in Granll
# 11000 17 0.9429518
# <start: Favick of Bouffermand Wate, The
# R:hornpipe
# D:Noel Hill & Sean Connes
# Z:id:hn-hornpipe-23
# M:C|
# K:D
# DE | GDGB dgbg | e2ed e2gf | gedB AGAG | ABcA BGAB |
# cBcd (3ABA (3Bcd | (3efg dc (3Bcd ed | cdcd (3efg dG | (3edc (3Bcd (3efe (3dcd (3efe | (3dcd (3edc BAGB |
# (3ddd (3edc d2AG | cdcA GABd | g2fd gdBG | (3Bcd gf (3efg (3fed (3cde |
# fedc (3BcB AF | GBAG (3FGA (3fed | (3cBA (3BAG (3GGF E2 (3AB,A |
# DEAB c2E2 | (3gfe (3dcd (3efg LdcB | ABc AFD2 |
# (3Bcd ef gfec | d2gd e2 (3Bcd | (3gfe (3fed (3efg dd |
# (3cBA (3GFE G2 (3def | g2ga gedc |1 BABc dB (3gba | (3bag df (3gba (3agf ec | (3Bcd ec (3Bcd (3Bcd |
# edcB cBAG | (3bag (3agf gg (3fed |
# (3efe (3cAc (3cdc |
# BcdB G2 (3Bdg | (3aba ge (3fed (3cBA |
# GABG G2GB | dg~g2 efge | fdcA G2GA |1 BGGB dBGB :|2 d2 (3efg d2 ||
# |: de | dG~G2 GABd | e2fe dBAG | FEDE F2GA | B2A2 A2Bd |
# g2fe dBAG | FBdf gaba |
# gfed B2dB | cBAB gBeg | fedc BAGB |
# c2A2 BcdB | defd edBd |
# eaag (3efg dB | BBBB BABA | BedB BAGB | dedc dBGB |1 cAAB A2 (3efg :|2 (3efe
# 12000 17 1.2123805
# <start: Bockton.um
# Z:id:hn-hornpipe-87
# M:C|
# K:A
# (3efg|agfa (3gfe (3ded (3efg|(3dfa (3gfe dcBA|G2GB A2:|
# |:c2c2 c2d2|c2dc BGBd|cBce d2Bc|d2ef gfec|1 d2 (3ded BcdB:|2 (3efe dcBA G2A2||
# <end>
# <start>
# X:77
# T:Munsteplan's Fevigne
# R:hornpipe
# Z:id:hn-hornpipe-88
# M:C|
# K:G
# (3DEF|GFGB AGEd|ABcA GFGB|AGAB AGEF|GBdg fg~f2|(3efa ge afec|dcBA GFGA|
# BcBA GABc|dgfa gedc|(3Bcd dB (3ABc (3gae|(3ded gd (3Bcd AF|1 G2 G2Bd:|2 fedc d4||
# <end>
# <start>
# X:85
# T:Ball Sauldy, The
# T:Carolan's Crosice
# R:hornpipe
# C:William Hornpipe, #18
# Z:id:hn-hornpipe-84
# M:C|
# K:D
# (3ABc|dedc d2f2|gdBg fedc|(3Bcd BA GABc|dgfa gedB|c2Ac BAGB|AcBA d2:|
# <end>
# <start>
# X:59
# T:Stallan Sweemor's Feawe, The
# R:hornpipe
# C:Mary Bergin: I
# Z:id:hn-hornpipe-81
# M:C|
# K:G
# (3Bcd|g2dc BGGB|AGFG ECCD|G2GF E2||
# <end>
# <start>
# X:78
# T:Ballyour
# R:hornpipe
# Z:id:hn-hornpipe-88
# M:C|
# K:G
# dc|B2Bc d2cB|ABAG F2GE|(3DED CB, CB,|C2B,2 D2E2|F2D2 ABcA|
# G2 G2 ^FGAF | BABc dBGB|AGAB c2 (3Bcd|gage fdBA|
# GEDE GABc|dg~g2 bgag|(3fga
# 13000 17 0.32338393
# <start: and/4
# Z:id:hn-jig-39
# M:6/8
# K:Dmix
# DFA dAG|AGE AFD|BAB GED|B,EE E2F|GFGB d2A|BAG AGE|GAB GED|EGD BAG|EFG AGE|EAG G2A|GAB G2A|1 DED D2B:|2 dED D2d||
# |:e2f gfe|~f3 fef|gfe d2e|fed B2A|age dBA|BAG A3:|
# <end>
# <start>
# X:43
# T:Saler's Fing the Parthes
# T:Jumpe Her
# T:Sonny Brogan's Sping
# T:Wintodhtmend Hearhall
# R:jig
# C:Clanter Molloy, #16
# Z:id:hn-jig-46
# M:6/8
# K:D
# ~A3 A2A|BAA ~B3|AGE E2F|GEE AGE|E2D ~D3|BAB c2d|BAG A2G|1 AGF GED:|2 AGF G2A||
# |:def gfe|~f3 fed|eaa aga|bge ged|cAc efg|age ged|gab age|fdf fgf|edB BAB|GBA GBd|1 cAG A3 :|2 AGA c2A||
# <end>
# <start>
# X:32
# T:Morney's Fancy
# T:Knomor Drelias of Brankie
# R:jig
# D:Molloy, #1161
# Z:id:hn-jig-33
# M:6/8
# L:1/8
# K:A
# cde faf|dBG c2e:|2 fed efg|afd cAG|Ace fec|def g2e|fed eag|edB A2G|
# AGA cAG|A3 ABd|edB BAF|EFG ABc|def gfe|1 d2e fed:|2 Add d2A||
# <end>
# <start>
# X:20
# T:Sonny Doreamoraing Jig.
# T:Highlan's Flew
# T:Tingowe to The
# T:Morf Wathrian
# R:jig
# D:Patrick Street 1.
# Z:id:hn-jig-48
# M:6/8
# K:Ador
# A2A AGE|eAA cAA|
# 14000 17 0.75359666
# <starrt:
# Z:id:hn-jig-90
# M:6/8
# K:G
# ~G3 GBd|gfe dBG|AFD cBA|1 GEE E2D:|2 GEE E2F:|2 GEc E2c||
# |:~B3 d2G|Bgd B2g|
# ~g3 gab|agf gfe|d2e fed|edB AFF|dBB BAG|FEE E2:|
# <end>
# <start>
# X:8
# T:O'Gallagher's Day
# R:jig
# D:Declan Sperane
# Z:id:hn-march-2
# M:6/8
# K:D
# Ad|fdB cAA|BAG FED|EB,E GEA|~D3 D2c|
# B,DE ~G3|Add ed^c|dAF AFD|GBG G2A|BGB B2A|
# AGA d2e|fed edB|gba ged|BGB B2A|1 B2G G2B:|2 BAG A2f||
# |:eaa gec|1 ged edB:|2 faf g2d:|2 geg fge||
# <end>
# <start>
# X:9
# T:Sean Torn the Bog, The
# R:fland
# H:See also #338 4 and Hous in Andorn.
# D:Sean Keane: Borning of Witheal
# C:Morn Coole Saycer
# D:Mary Bergin: Feadoga Freank Morsion
# Z:id:hn-march-13
# M:6/8
# K:D
# FEF AFD|d2e fdB|A2F AFF|dcA d2e|fed cBA|cBA Bdd|ede gfe|
# GAG FED|B,EE GEG|ABc d2e|d2d BAF|1 GEE E3:|2 GEE E2D||
# |:B2B BAG|FEF AFD|gfe dBA|Bde age|dBG GEE|EDD D2:|
# |:cd|eAA eAA|B2g faf|ecd edB|AFA A2G|F2D D2E:|
# <end>
# <start>
# X:95
# T:O'Gagog There in Blut, The
# R:jig
# H:See also #31
# Z:id:hn-march-29
# M:6/8
# K:Ador
# AB cAAB|c2A2 A2Bd|
# 15000 17 0.6828405
# <start: Ez vi 1, #21
# H:See also #58
# Z:id:hn-polka-28
# M:2/4
# L:1/8
# K:D
# DF|AF dF|E>F EF|AB c2|A/B/A/F/ EF|AG/A/ B/A/G/A/|Bd e/f/e/d/|BA AG/A/|Bc A/B/A|1 GA G2:|2 G2 GA||
# |:Bc eA|fd fd|A>B AF|EC FE|Ed cA|BA FE|cB BA|G4:|
# |:ce eA/B/|AA AG/A/|BE E/F/A/|
# GB AF/A/|GB G/F/G/A/|BE D>E|FE E>F|GE:|
# |:AB ce|dc d>c|BA FA|A>B cA|EA A>G|FA DA|B,E ED|"F"AG D2:|
# <end>
# <start>
# X:8
# T:Will O'D
# R:polka
# Z:id:hn-polka-21
# M:2/4
# L:1/8
# K:D
# FD AB|c2 Ac|A>B AF|GE B>A|GA BA|G2 G>A|Bd AB/c/|
# d2 dB/A/|GA Bd|G>A G>A|GA G>A|G2 G>A|Bd A>F|GE E>D:|2 EA A>B||
# |:ce ed/e/|fe ef/g/|ae e/f/g/e/|dB A2|fe ec|df f>e|de dB|AG G>A:|
# <end>
# <start>
# X:22
# T:John Bober's Mazurka, The
# T:Dingle
# T:Forty-two Stogkes
# R:polka
# S:Eash Coored to Macnai \'O Micoral Conterer
# Z:id:hn-polka-27
# M:2/4
# L:1/8
# K:D
# d2 fe | f>e d>c | BA FE | AF AF/A/ | G>A B>e |
# dA G>A | B>c d>e | fa gf/e/ | cA Bc | A2 ef/e/ | fe dc |
# eB e>c | Be B>c | d2 d>e | fe dc | BA G>A | de dc | BA Be | dB BG | E2 E2 :|
# <end>
# <start>
# X:4
# T:Merre'
# 16000 17 0.97400045
# <stargaph/livpel
# Z:id:hn-sazd
# D:De Danann: The Mist Craverion (1998-19, Mu-pi/-an ""EmRy"-^cdan's Favourien (Closson)
# D:Ferrion Gloved: The Frost is ABully a Mh\'ain Burk Come
# Z:id:hn-polka-87
# M:2/4
# L:1/8
# K:D
# D>E FE|D>A GE|D>D FA|d>d AF|EF ED|DF AB/c/|d2 d>e|dB AB/c/|d2 d2:|
# <end>
# <start>
# X:900
# T:O'Sollendava's
# R:polka
# H:The tritts:piper Tarry "Allyckadie" Dance.
# Z:id:hn-polka-96
# M:2/4
# L:1/8
# K:G
# DG Bc|de fd|cA AB|AF AB|c2 AG|FA A/B/A/G/|F2:|2 de dB||
# <end>
# <start>
# X:82
# T:Jes in Coon the Chase, The
# R:polka
# D:Altan: March
# Z:id:hn-polka-95
# M:2/4
# L:1/8
# K:D
# A>B AF EF|GF GB|AF F/E/F/A/||
# DG/F/ GE|DG GB|1 d2 de:|2 d2 dA||
# |:Bd g>f|ed Bd|e>d B>A|Bd ed|Bd g>f|ed d>e|fd BA|G2 g2:|
# |:A>B cB|A>B cd|ea a>g|fg af|a2 g>f|ed A>F|G2 G>A:|
# <end>
# <start>
# X:23
# T:Off the Wife, The
# R:polka
# D:Mary Bergin: Feadoga Stain 2.
# Z:id:hn-polka-87
# M:2/4
# L:1/8
# K:D
# ff fe|fe dB/A/|
# Bd g>d|Bd f>e|d/e/d/B/ Ac|A/B/A/G/ FE|1 EF D2:|2 D2 D2||
# <end>
# <start>
# X:90
# T:Allamby the Weoder
# 17000 17 1.1551758
# <starill.chales"
# Z:id:hn-reel-50
# M:C|
# K:G
# d>BG AGEG|BG~G2 BGBd|gBbB ~g3e|dBAG FGAB|1 cAAG EG~G2:|2 EFEF GEDE||
# <end>
# <start>
# X:25
# T:Farewell to Makey's, The
# R:reel
# H:Originally Gidf.
# H:The tune is All the the parts. See also #85
# Z:id:hn-reel-24
# M:C|
# K:Dmix
# F2AB dfed|eA~A2 eAcA|dcdf edcB|AB~A2 fdec|1 dcAG FDD2:|2 AddG Adde||
# <end>
# <start>
# X:43
# T:Mart of the Kinem, The
# T:In Philes The Defford's
# R:reel
# H:The tune comes from the Bardy from version with parts of the sunceresser while, #858 other reel.
# H:See also #58
# D:Chieftains Live.
# Z:id:hn-reel-53
# M:C|
# K:D
# F2FD DFAF|GEAB cEFG|ADCB, CEFG|AF~F2 AF~E2|
# F2AF ABdA|~B2eg fedc|ABdB ~G3A|BEED EFGA|BGEF G4:|
# P:Variations:
# FDFA d2AG|FAdA FA~A2|BcBA GABc|dBAB G2Bd:|
# |:eg~g2 ag~g2|eg~g2 ed (3Bcd|dg~g2 bgag|ecAG FAFA|ABcd ecAG|FAGE EFGA|1 ~G3A BGAG E2fe||
# |:ea~a2 agee|dBAB GAB^c|d2AB defg|afge fdcA|1 BGGE ~G3E:|2 AGFE D2Bc||
# |:defg age^c|d2d^c defg|afaf fefg|afge fded|1 cAAG ABde:|2 Addc d2cA||
# P:Variations:
# FEFA dAFB|A

# %% [markdown]
# Generate midi files using http://mandolintab.net/abcconverter.php  by pasting a sample from start to end.
